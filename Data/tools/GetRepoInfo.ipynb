# %%
import requests
import json
import time
from datetime import datetime
import os.path

# %%
channel1 = "ScikitLearn"
GitHub_folder = "./GitHubProfile/"
Gitter_folder = "./GitterRoomUsers/"

# %% [markdown]
# ## Retreive users from Gitter

# %%
usernames = []
users = []

# %%
# Channel: https://gitter.im/scikit-learn/scikit-learn
roomId = "541a528c163965c9bc2053e1"
gitter_token = "da39366c19eee4952e84e387ae76049e04015917"
#pagination
skip_num = 0
users_link = "https://api.gitter.im/v1/rooms/"+roomId+"/users?access_token="+gitter_token+"&limit=100&skip="+str(skip_num)

while True:
    api_link = requests.get(users_link)
    users_data = api_link.json()
    if len(users_data) == 0:
        break
    
    for num in range(len(users_data)):
        dict_user = {}
        dict_user["id"] = users_data[num]["id"]
        dict_user["username"] = users_data[num]["username"]
        usernames.append(users_data[num]["username"])
        dict_user["displayName"] = users_data[num]["displayName"]
        
        users.append(dict_user)
    
    skip_num += 100
    users_link = "https://api.gitter.im/v1/rooms/"+roomId+"/users?access_token="+gitter_token+"&limit=100&skip="+str(skip_num)

print("Total users: ",len(users))
# Out:
# Total users:  4318

# %%
len(usernames)
# Out:
# 4318

# %%
#save user meta data
with open(Gitter_folder+channel1+'.json', 'w') as outfile:
    json.dump(users, outfile)

# %%
#save usernames
with open(Gitter_folder+channel1+'_usernames.txt', 'w') as fp:
    for name in usernames:
        # write each item on a new line
        fp.write("%s\n" % name)
    print('Done')
# Out:
# Done

# %% [markdown]
# ## Retreive user profile from GitHub

# %%
usernames = []

# %%
#read usernames from saved files
with open(Gitter_folder+channel1+'_usernames.txt', 'r') as fp:
    for line in fp:
        # remove linebreak from a current name
        # linebreak is the last character of each line
        x = line[:-1]

        # add current item to the list
        usernames.append(x)

# display list
print(len(usernames))
# Out:
# 4318

# %%
users_not_found = []
with open(Gitter_folder+channel1+'_nofile.txt', 'r') as fp:
    for line in fp:
        # remove linebreak from a current name
        # linebreak is the last character of each line
        x = line[:-1]

        # add current item to the list
        users_not_found.append(x)

# %%
time_to_sleep = 10*60
for username in usernames:
    username = username.strip()
    if os.path.exists(GitHub_folder+username+'.json') or username in set(users_not_found):
        continue
    
    #rate limit default = 30 per page, retreive data from all pages
    page = 1
    link = "https://api.github.com/users/"+username+"/repos?per_page=100&page="+str(page)
    repos = []
    count = 1
    while True:
        api_data = {}
        api_link = requests.get(link, auth=("NoleWang","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"))
        api_data = api_link.json()
        if len(api_data) == 0:
            break
        elif "name" not in json.dumps(api_data):
            if "API rate limit exceeded" in api_data["message"]:
                #time_to_sleep = (60 - datetime.now().minute + 1)*60
                print("Reach limit! Sleep ",time_to_sleep, " seconds!")
                time.sleep(time_to_sleep)
                link = "https://api.github.com/users/"+username+"/repos?per_page=100&page="+str(page)
                continue
            break
                
            
    
        for num in range(len(api_data)):
            repo_name = api_data[num]["name"]
            #print(count, ": ",repo_name)
            #readme_link = "https://api.github.com/repos/"+username+"/"+repo_name+"/readme"
            lan_link = "https://api.github.com/repos/"+username+"/"+repo_name+"/languages"
            lan_data = requests.get(lan_link, auth=("NoleWang","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")).json()
            while "message" in json.dumps(lan_data) and "API rate limit exceeded" in lan_data["message"]:
                print("Reach limit! Sleep ",time_to_sleep, " seconds!")
                time.sleep(time_to_sleep)
                lan_data = requests.get(lan_link, auth=("NoleWang","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")).json()
                
        
            dict_user = {}
            dict_user["name"] = repo_name
            dict_user["url"] = api_data[num]["html_url"]
            dict_user["description"] = api_data[num]["description"]
            dict_user["language"] = list(lan_data.keys())
            dict_user["forks_count"] = api_data[num]["forks_count"]
            dict_user["stargazers_count"] = api_data[num]["stargazers_count"]
            dict_user["watchers_count"] = api_data[num]["watchers_count"]
            dict_user["size"] = api_data[num]["size"]
            dict_user["topics"] = api_data[num]["topics"]
        
            repos.append(dict_user)
            count += 1
        page += 1
        link = "https://api.github.com/users/"+username+"/repos?per_page=100&page="+str(page)
        
    
    print(username,": ",len(repos)," repos")
    if len(repos) == 0:
        users_not_found.append(username)
    else:
        with open(GitHub_folder+username+'.json', 'w') as outfile:
            json.dump(repos, outfile)
# Out:
# jsmaxim :  39  repos
# jevanio :  19  repos
# prod1k_twitter :  0  repos
# twanito :  26  repos
# huangjun6 :  12  repos
# muahahaha :  5  repos
# mwitiderrick :  90  repos
# george-azzari :  3  repos
# vladzima :  21  repos
# BethanyG :  63  repos
# SaurabhGupta49 :  0  repos
# abdullahkhilji :  45  repos
# shreybatra :  75  repos
# daftengineer :  10  repos
# janjagusch :  108  repos
# TPalawaT :  11  repos
# Saranbfinch :  5  repos
# vinayvm :  6  repos
# pohyk123 :  22  repos
# stevenQinwen :  6  repos
# catherinelee274 :  28  repos
# wsjfc :  12  repos
# a1ext :  20  repos
# duskybomb :  38  repos
# Dalttony :  11  repos
# rockstar777 :  0  repos
# madhuracj :  19  repos
# ssameer21 :  0  repos
# Jeeva-Ganesan :  23  repos
# clairtonm :  14  repos
# dutraleonardo :  15  repos
# JonathanQiangLi :  7  repos
# aditya2000 :  83  repos
# Baneeishaque :  647  repos
# ansh103 :  21  repos
# jayaeu_twitter :  0  repos
# BIAOXYZ :  76  repos
# jonalivi__twitter :  0  repos
# jassoncasey :  6  repos
# SanjayRathod033 :  4  repos
# keshavkmr48 :  24  repos
# lqdev :  95  repos
# istom1n_twitter :  0  repos
# bobonice :  0  repos
# thehitechpanky :  7  repos
# MIsmailKhan :  11  repos
# jaketalyor32325 :  4  repos
# pamin2222 :  18  repos
# Maxima86 :  0  repos
# johnmatrix34 :  0  repos
# aph61 :  4  repos
# SeanRajnis_twitter :  0  repos
# jarrelldunson :  7  repos
# aarck :  0  repos
# RayDayBaby :  0  repos
# OlegBaskov :  19  repos
# Pimp_Fada_twitter :  0  repos
# janzaib-masood :  0  repos
# rohangupta :  14  repos
# itsmegaurav :  12  repos
# SriniVest :  344  repos
# ditsme :  4  repos
# katsar0v :  9  repos
# sddhrthrt :  56  repos
# PatInshuti :  33  repos
# gertjandemulder :  9  repos
# kingmbc :  134  repos
# jacobcvt12 :  83  repos
# jaznups :  2  repos
# gilbertoolimpio :  31  repos
# ppaanngggg :  26  repos
# CoolSheng :  0  repos
# GitYbc :  0  repos
# DieDen9 :  6  repos
# jarlva :  2  repos
# NikitaMandhani_twitter :  0  repos
# KiriteeGak :  37  repos
# varsha6319 :  26  repos
# macshaggy :  10  repos
# GitTorres_twitter :  0  repos
# bghanchi :  46  repos
# wdevazelhes :  17  repos
# SoorajN :  0  repos
# machine-uprising :  15  repos
# jeffreyrufino :  3  repos
# grashika :  0  repos
# sechilds :  56  repos
# jeinsle :  4  repos
# jailad :  19  repos
# aneekroy :  51  repos
# abhi-jha :  323  repos
# fabiomolinaruol :  0  repos
# xlhaw :  24  repos
# nicoa :  10  repos
# Labout :  19  repos
# jsmm :  3  repos
# ReZeroS :  27  repos
# CapetillLily_twitter :  0  repos
# robrivas :  0  repos
# anacost :  55  repos
# ChikuChinki_twitter :  0  repos
# jtkiley :  14  repos
# johannspies :  1  repos
# limitup :  22  repos
# aalizwel23 :  39  repos
# ValentinCalomme :  10  repos
# shauryashaurya :  52  repos
# Fenil3510 :  0  repos
# fdemesmaeker :  3  repos
# mikofski :  83  repos
# apuayush :  72  repos
# ashwanidv100 :  194  repos
# ananduri :  18  repos
# wckdouglas :  93  repos
# officialsandeep87 :  6  repos
# joelbits :  2  repos
# Sahanave :  24  repos
# Alec007 :  0  repos
# kmjawadurrahman :  39  repos
# gcbeltramini :  19  repos
# joaoavf :  27  repos
# goswami-rahul :  22  repos
# xu-song :  60  repos
# nocibambi :  25  repos
# niklasschmitz :  37  repos
# yangyudaddy :  26  repos
# ShadowGimmick_twitter :  0  repos
# skvorekn :  19  repos
# albertvillanova :  317  repos
# IsuraNimalasri :  223  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# koperak :  18  repos
# davidsmandrade :  30  repos
# panstav1 :  19  repos
# rahulKumar-dev :  11  repos
# rafarui :  20  repos
# tktrungna :  7  repos
# akashp1997 :  29  repos
# chakify_twitter :  0  repos
# think-high :  14  repos
# Harshithasaiynar :  5  repos
# wqw547243068 :  134  repos
# murugesh-smp :  37  repos
# aayushkumarjvs :  24  repos
# CodeDem :  40  repos
# ravikiran0606 :  62  repos
# TaceyWong :  140  repos
# lm_mor_twitter :  0  repos
# uservipin :  23  repos
# mcasl :  9  repos
# nariyapratik :  2  repos
# mcilieSocket :  0  repos
# nicoandmee :  49  repos
# cyberjag :  30  repos
# vxpofvl_twitter :  0  repos
# muasiq_twitter :  0  repos
# vinayakkgarg :  54  repos
# rafalpronko :  12  repos
# vkvaibhav669 :  39  repos
# milaroisin :  0  repos
# 0283K__twitter :  0  repos
# mlage :  2  repos
# idahmed :  9  repos
# githubartist :  2  repos
# srikanth3435 :  4  repos
# ahmrashiduzzaman :  12  repos
# Tranquangdai :  11  repos
# kaelgabriel :  8  repos
# ewards :  18  repos
# Sharmila8 :  20  repos
# AtuNuka :  0  repos
# BrainlessLabs :  50  repos
# DishinGoyani :  16  repos
# sumitskumar :  8  repos
# Rocco9900 :  2  repos
# Jonathan-Wei :  40  repos
# GeorgeLeung :  7  repos
# fbkch :  22  repos
# dewshr :  13  repos
# quant12345 :  2  repos
# Akram1234 :  20  repos
# gaurav214 :  20  repos
# qytz :  39  repos
# varunshukla :  12  repos
# Cobord :  34  repos
# alvarlaigna_twitter :  0  repos
# LucijaGregov :  17  repos
# minskeyguo :  11  repos
# sohaibomr :  27  repos
# tottokug :  92  repos
# yuchuqin :  13  repos
# debdip :  8  repos
# tjefferson518_twitter :  0  repos
# NovaOutlaw :  0  repos
# shunnnn :  0  repos
# nagellette :  26  repos
# echolabstech :  19  repos
# bintangthunder :  12  repos
# rakeshkurakula :  18  repos
# jmetzz :  53  repos
# stantonxu :  33  repos
# vrra :  7  repos
# snastase :  60  repos
# isakdiaz :  21  repos
# ritjos12345 :  44  repos
# CurtLH :  67  repos
# 11383979taki :  0  repos
# OlehKSS :  48  repos
# JoElfner :  6  repos
# amarrerod :  82  repos
# adadesions :  174  repos
# tripleday :  16  repos
# aljosabilic :  2  repos
# Davidadebiyi :  6  repos
# alyeffy :  11  repos
# Nujcharee_twitter :  0  repos
# Sevistuo :  104  repos
# bbuluttekin :  23  repos
# mzaman07 :  46  repos
# _morten__gitlab :  0  repos
# sriram2093 :  12  repos
# ci-yang :  22  repos
# saddathasan :  40  repos
# deltavin :  0  repos
# nothinghappens :  0  repos
# Phinneas :  45  repos
# priyanknamdev :  6  repos
# XiaoLisp_twitter :  0  repos
# illyanyc :  17  repos
# rakesh491 :  13  repos
# sidarth16 :  14  repos
# jishnuchandran2026_gitlab :  0  repos
# prashantsinha201 :  3  repos
# Chandrak1907_twitter :  0  repos
# kedong2014 :  30  repos
# tommy-0 :  0  repos
# ccenzura :  5  repos
# zhengwenjiee :  0  repos
# ishubhamgupta :  31  repos
# JK87iab :  5  repos
# 13idyut :  5  repos
# jack-1_gitlab :  0  repos
# VitalyAnkh :  42  repos
# CatNofishing :  4  repos
# binson-b :  14  repos
# aryunaabhay_twitter :  0  repos
# khaneisti :  4  repos
# craigeddy :  61  repos
# AMaini503 :  22  repos
# OuailAb_twitter :  0  repos
# rvprasad :  15  repos
# mstepanovic :  7  repos
# acbetter_gitlab :  0  repos
# MahmoudElsayad :  12  repos
# ayushmangupta1990 :  16  repos
# mlafore3 :  0  repos
# S1xe :  11  repos
# johnnync13 :  0  repos
# ksofa2 :  55  repos
# Gagalin :  24  repos
# aKesav :  1  repos
# tejaAPI :  12  repos
# mtjvankuik :  22  repos
# GeneKao :  51  repos
# dboeckenhoff :  6  repos
# krassowski :  168  repos
# bishnumurmu :  14  repos
# LarsHH :  14  repos
# legout :  10  repos
# ayushj_jain_twitter :  0  repos
# RK-kondapally :  0  repos
# dicicch :  12  repos
# georgipeev :  1  repos
# pikaliov :  178  repos
# PauloFRC :  19  repos
# huixiao1_twitter :  0  repos
# sumittomar99 :  3  repos
# ameynaik :  0  repos
# manaswinvyas :  0  repos
# ysinjab :  53  repos
# vimal-honest :  1  repos
# michaelabehsera_twitter :  0  repos
# dengxiangcheng :  0  repos
# ilmucio :  5  repos
# rohitharitash :  6  repos
# kurwazavr :  1  repos
# LoveHeartFly :  2  repos
# imlegend19 :  49  repos
# RiteshThalla_twitter :  0  repos
# jmohit13 :  16  repos
# Sophronisba :  0  repos
# Sumindar :  69  repos
# kush99993s :  47  repos
# fcarbon_gitlab :  0  repos
# JinkaSyamkumar :  11  repos
# bhavikv9488 :  8  repos
# joertlin :  8  repos
# KeshavKundal :  0  repos
# gaurav3210 :  36  repos
# rsenthilkumar6 :  17  repos
# snifhex :  88  repos
# maykef :  36  repos
# grzeko_twitter :  0  repos
# meta_kato_twitter :  0  repos
# hojsad :  2  repos
# msauhta :  9  repos
# SofianeSarni_twitter :  0  repos
# srniranjan :  9  repos
# talatccan :  4  repos
# orenpx :  2  repos
# kaeken1jp :  41  repos
# SimSimmm :  1  repos
# Neithard :  8  repos
# toppare_twitter :  0  repos
# JefeLitman :  17  repos
# carbolymer :  41  repos
# Aaravmaheshwari :  1  repos
# AvipsaRoy_twitter :  0  repos
# mgurdal :  42  repos
# thecreepaccess :  0  repos
# nguyenth-ntu :  0  repos
# ssghost :  529  repos
# lokendrasolanki :  4  repos
# nrydevops :  0  repos
# harshithas8_twitter :  0  repos
# FrndzAreSelfish_twitter :  0  repos
# SwordKnight6216 :  15  repos
# annaayzenshtat :  4  repos
# mepa :  35  repos
# Senapati_gitlab :  0  repos
# Freija :  9  repos
# shubham-pramanick :  2  repos
# Borda :  66  repos
# FollowKenny :  16  repos
# samronsin :  9  repos
# jbschiratti :  16  repos
# jeremiedbb :  29  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# likeabhi :  10  repos
# farman32 :  0  repos
# TianqiJiang :  19  repos
# albertcthomas :  10  repos
# mauer_franz_twitter :  0  repos
# infosect0r_twitter :  0  repos
# Daipeng3_twitter :  0  repos
# javiqm12 :  20  repos
# likith012 :  23  repos
# andreyaltunin :  0  repos
# Ishaan28malik :  91  repos
# netskink :  115  repos
# mloning :  34  repos
# JefferyLWY :  0  repos
# rigid-logician :  5  repos
# AaronCode31 :  1  repos
# tamend92 :  7  repos
# gkourogiorgas :  8  repos
# prajwalsaokar :  9  repos
# AungMyat993 :  0  repos
# leeweizhe1993 :  5  repos
# rodalbert :  28  repos
# jacobjkwu :  10  repos
# sahilgandhi94 :  32  repos
# Johny-kann :  17  repos
# na399 :  36  repos
# karanjakhar :  79  repos
# matthewstidham :  90  repos
# JomaMinoza :  74  repos
# yangsuo :  112  repos
# margimenez :  2  repos
# victor-lf :  69  repos
# RhoNit :  14  repos
# wjy521996 :  0  repos
# shubhankar0909_twitter :  0  repos
# ll0816 :  32  repos
# MFizz :  16  repos
# debasishdebs :  9  repos
# Sriharsha-hatwar :  26  repos
# Vijay_NT_twitter :  0  repos
# csrwl :  4  repos
# datajanko :  13  repos
# faichele :  17  repos
# diptangsu01 :  3  repos
# tosen1990 :  45  repos
# Chandramani2 :  2  repos
# washing1127 :  5  repos
# ameensidhique :  0  repos
# shanjgit :  64  repos
# voiceless :  2  repos
# codeninja97 :  1  repos
# DuongTSon :  5  repos
# shawnlinxl :  46  repos
# shwetasit :  15  repos
# chuckll :  10  repos
# m-clare :  49  repos
# nisnt2411 :  2  repos
# xaneon :  18  repos
# evinism_twitter :  0  repos
# shreyanshg2010 :  41  repos
# datA2Z :  2  repos
# Srinath-V-S :  23  repos
# SainJ :  0  repos
# cuebster_gitlab :  0  repos
# bitscoder_twitter :  0  repos
# jrbrowny :  1  repos
# RanjithKumar003 :  0  repos
# jrvangogh :  4  repos
# qk1997 :  33  repos
# ZAZA316 :  5  repos
# hungnguyengoc :  182  repos
# Learning191 :  0  repos
# belgacea :  15  repos
# ayselgenczengin :  9  repos
# kunalvats :  35  repos
# clicly :  42  repos
# SantoshML :  31  repos
# naveedn :  28  repos
# JoshuaQYH :  20  repos
# dubesar :  131  repos
# abrew1A :  0  repos
# sanjaydatasciencedojo :  93  repos
# eliaborras :  3  repos
# balavenkatesh3322 :  35  repos
# lfunderburk :  76  repos
# Ritzing :  109  repos
# adsmaniotto :  18  repos
# samanthkumar :  2  repos
# mferrari3 :  15  repos
# pszajows :  5  repos
# andreanr :  21  repos
# dwibedis :  22  repos
# samuelbartels20 :  48  repos
# Ujjawal-K-Panchal :  37  repos
# mitrish :  30  repos
# v3rm1 :  37  repos
# abecadel :  140  repos
# teckdeja :  0  repos
# sofymar :  3  repos
# jtrakk :  25  repos
# jaganadhg :  54  repos
# yangjingbo0805 :  7  repos
# florentpietot :  0  repos
# lucifermorningstar1305 :  19  repos
# Teut2711 :  28  repos
# Sunilrai486 :  53  repos
# KiranGkiran11_twitter :  0  repos
# Akash-Sharma-1 :  48  repos
# MePiyush :  4  repos
# eslintpurity :  64  repos
# mx9 :  2  repos
# melsyt :  10  repos
# LisaThomas9 :  11  repos
# Hadeishi :  24  repos
# Prakashpkdskd_twitter :  0  repos
# theamazingclark_twitter :  0  repos
# Mariam-ke :  23  repos
# elinsun :  8  repos
# harpalsahota :  7  repos
# vl21 :  0  repos
# shimengfeng :  16  repos
# reshamas :  73  repos
# shuyangzhang :  26  repos
# NicolasHug :  58  repos
# rebekahkim :  21  repos
# nycuni :  10  repos
# rpeb :  24  repos
# heytanay :  122  repos
# OsamaEhsan :  7  repos
# albertauyeung :  27  repos
# zzj0402_gitlab :  0  repos
# gostkowski :  2  repos
# fredvb :  9  repos
# nandhinianandj :  20  repos
# sravan498 :  7  repos
# KoulickS :  38  repos
# Ngamlana :  0  repos
# sandeepkumarsahoo :  14  repos
# femonofsky :  78  repos
# guitor4 :  5  repos
# Kstheking :  47  repos
# vivek14632 :  32  repos
# NeelavaChatterjee :  7  repos
# alegonz :  19  repos
# thepumpadvisor_twitter :  0  repos
# GONZALORUIZR_twitter :  0  repos
# vaibssingh :  42  repos
# fredabood :  11  repos
# PistonY :  33  repos
# FazeelUsmani :  76  repos
# pietroppeter :  54  repos
# 0x00000024 :  32  repos
# Asrst :  37  repos
# pradeepp_90_twitter :  0  repos
# Girrajjangid :  41  repos
# umedsondoniyor :  66  repos
# AntonPeniaziev :  11  repos
# jaysonzhao :  124  repos
# ayanbag :  45  repos
# mj555 :  5  repos
# charlesbeckwith :  6  repos
# dhwanishah :  31  repos
# skeptycal :  274  repos
# omc89 :  30  repos
# pooshan.vyas_gitlab :  0  repos
# MVenkat_28_gitlab :  0  repos
# sasan-j :  56  repos
# xiaoqing928 :  6  repos
# vikrantlw :  3  repos
# pwadlington :  30  repos
# kshigeto_twitter :  0  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# hushinghai :  69  repos
# AbhishekBabuji :  17  repos
# zorrotrying :  79  repos
# chaitanya-baraskar :  10  repos
# pms141 :  0  repos
# JaeyeongYang :  6  repos
# dax-1895 :  7  repos
# a5a :  11  repos
# CloudChaoszero :  24  repos
# theimgclist :  57  repos
# siddhantdesai :  8  repos
# cihanerman__twitter :  0  repos
# Palash1995 :  0  repos
# ek-nath :  34  repos
# OlimpioGilberto_twitter :  0  repos
# Doc-Scott :  12  repos
# Exomemory :  1  repos
# mavavilj :  6  repos
# giswqs :  203  repos
# MBvisti :  8  repos
# 12VISHESH :  32  repos
# LucianaMarques :  170  repos
# escapize :  0  repos
# _ArchEnemy__gitlab :  0  repos
# pierreglaser :  50  repos
# amberbhanarkar :  19  repos
# LingxB :  5  repos
# hassaanseeker :  34  repos
# harimaruthachalam :  29  repos
# Balu-Varanasi :  115  repos
# MaxHalford :  78  repos
# camimariane_twitter :  0  repos
# monkeyxite :  17  repos
# luisminero_gitlab :  0  repos
# s0magome :  0  repos
# yzylining :  12  repos
# ShubhamKJha :  65  repos
# mdnur89 :  17  repos
# iStochastic :  3  repos
# adityap31 :  14  repos
# ChenYeadong :  4  repos
# Behzadb :  16  repos
# spectre1811 :  14  repos
# vinayya :  125  repos
# rtmatx :  0  repos
# pascal-mueller :  5  repos
# sajjass :  14  repos
# mikezime :  9  repos
# volgad :  0  repos
# lowjack1 :  15  repos
# abeppu_twitter :  0  repos
# MohamSayed :  22  repos
# firekay :  39  repos
# DrewMcArthur_gitlab :  0  repos
# aanand2300 :  14  repos
# RajatGarg97 :  142  repos
# david-cottrell_gitlab :  0  repos
# chiragu :  5  repos
# fwapy :  0  repos
# enricorotundo :  40  repos
# bravoPan :  38  repos
# AGoodDataScientist :  6  repos
# phonginx :  0  repos
# MVSTY :  1  repos
# justmarkham :  38  repos
# ramgsuri :  55  repos
# human098 :  0  repos
# aussenrist15 :  0  repos
# galal27 :  13  repos
# gollum_here_twitter :  0  repos
# DeqiTang :  6  repos
# rhnux :  13  repos
# gmg0829 :  71  repos
# adrianvaneeden :  18  repos
# Abner199 :  21  repos
# gyrdym :  9  repos
# Rawkush :  65  repos
# johnmelodyme :  838  repos
# thomascherickal :  447  repos
# karkhanisvinayak :  5  repos
# sshopov :  6  repos
# ahujaraman :  15  repos
# alanding1989 :  182  repos
# sankarsp :  100  repos
# RichGit101 :  204  repos
# sakshichopkar :  7  repos
# abbas-salimi :  40  repos
# steve7158 :  55  repos
# enigmaassissinator :  0  repos
# hamaadshah :  11  repos
# VincentK16 :  111  repos
# dufftt :  21  repos
# majed316 :  5  repos
# amitkumarbalaji_twitter :  0  repos
# mtsokol :  41  repos
# MangalGoyal_twitter :  0  repos
# bumblebee96 :  4  repos
# ishanendou :  0  repos
# TonyFly2000 :  2  repos
# sameshl :  25  repos
# colin-bethea :  11  repos
# fangjyshanghai :  235  repos
# ylitormatech :  15  repos
# JerryMatera :  29  repos
# AnkurRyder :  36  repos
# FranciscoPalomares :  16  repos
# aparkerlue :  24  repos
# fsinghoff :  4  repos
# justingoheen :  24  repos
# athishsreeram :  38  repos
# iKausik :  24  repos
# RohitMidha23 :  24  repos
# smjle :  6  repos
# ronitneve_twitter :  0  repos
# Timiyu :  26  repos
# egy1st :  43  repos
# AshishAYadav :  30  repos
# clusterer :  2  repos
# WiltonH :  12  repos
# OudarjyaS_twitter :  0  repos
# teetangh :  24  repos
# fusion-c :  5  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# bonn0062 :  70  repos
# komalahuwalia :  15  repos
# mmanchem :  58  repos
# ic1396 :  10  repos
# maham8668 :  4  repos
# lp-dataninja :  44  repos
# apundhir :  25  repos
# Devendrasharma13 :  24  repos
# artemiygr_gitlab :  0  repos
# Arvind-Kumar-Agrawal :  4  repos
# bellahcenmarwane :  15  repos
# priyanka503 :  10  repos
# SHANMUKHA-VENKAT :  0  repos
# KartikShrivastava :  28  repos
# codeslord :  195  repos
# jamesthatcher :  0  repos
# isaacaugustus :  3  repos
# vaibhavjain30699 :  37  repos
# algo-circle :  34  repos
# suhongs :  7  repos
# Murithijoshua :  90  repos
# troykirin :  43  repos
# ms314u :  2  repos
# whiteashleye :  5  repos
# lesongvi :  90  repos
# danaja :  17  repos
# dan_3213_twitter :  0  repos
# dorbodwolf :  112  repos
# tylerkontra-system1 :  1  repos
# ddxv :  22  repos
# bayerb :  0  repos
# abenbihi :  28  repos
# pcoliveira00 :  40  repos
# Gk8143197049 :  3  repos
# ky-zhang :  0  repos
# thomasjpfan :  212  repos
# prashant1k99 :  64  repos
# ajflores1604 :  9  repos
# puneeth2001 :  73  repos
# SourojitDas :  9  repos
# SiluPanda :  52  repos
# zinark :  19  repos
# utsavpatel51 :  26  repos
# hemantj99 :  39  repos
# yuju1981_gitlab :  0  repos
# gabrielboiero :  11  repos
# yugaljain1999 :  75  repos
# SimonCW :  34  repos
# LauJohnney_twitter :  0  repos
# janvi04 :  51  repos
# Inventitech :  58  repos
# SaoYan :  16  repos
# robotjellyzone :  105  repos
# Marviel :  64  repos
# mak2296 :  14  repos
# pedromclamas_twitter :  0  repos
# cmarmo :  45  repos
# SadatAliH :  3  repos
# Um3sobi :  8  repos
# dorfarber :  0  repos
# stelios357 :  62  repos
# scuervo91 :  40  repos
# nitinnat :  47  repos
# li1127217ye :  6  repos
# skgtrx :  15  repos
# glasgowm148 :  53  repos
# radheshyam999 :  38  repos
# norbusan :  73  repos
# BackDor3_twitter :  0  repos
# vpa-es :  0  repos
# EmbolismSoil :  96  repos
# adam2392 :  97  repos
# bohlmannc :  7  repos
# SciEvan :  250  repos
# ravivarapuk :  12  repos
# SadiaAman :  3  repos
# jrich8573 :  39  repos
# tdcollingsworth :  0  repos
# ANIGRE :  14  repos
# Navid61 :  2  repos
# debashish-roy :  10  repos
# XBTinChina :  16  repos
# theirfansayed_gitlab :  0  repos
# JohanMonster :  6  repos
# GMovesChess :  22  repos
# ramapriyakp :  19  repos
# kalycoding :  20  repos
# vcashk :  138  repos
# Stack0149_twitter :  0  repos
# haakonhr_gitlab :  0  repos
# pujaarajan :  32  repos
# orlandobcoelho :  0  repos
# roshni-b :  24  repos
# piyushagarwal08 :  50  repos
# mathtick_twitter :  0  repos
# begrossi :  26  repos
# leechangyo :  200  repos
# sandroci :  9  repos
# Pahandrovich :  27  repos
# LucyJimenez :  39  repos
# qecelab :  1  repos
# MehdiChelh :  30  repos
# josedaudi :  36  repos
# adriente :  4  repos
# paulonteri :  46  repos
# harbi811 :  41  repos
# zhuwenjian :  26  repos
# logsvikas :  0  repos
# El-anqiao :  76  repos
# dhruvagupta2014 :  32  repos
# AdamZh0u :  23  repos
# CooperData :  10  repos
# ignaciosotoz :  5  repos
# bkos :  1  repos
# KaueMaia :  20  repos
# tonarinohey :  5  repos
# ypeanng :  22  repos
# shivamangal :  0  repos
# alexsun8373 :  0  repos
# Arumugamvasu :  10  repos
# rteja1113 :  11  repos
# flo2506_twitter :  0  repos
# Jo-Fleck :  17  repos
# meSubhoKarma :  0  repos
# fwille :  3  repos
# xiligey :  13  repos
# Payam-Ebadi :  2  repos
# muokicaleb :  91  repos
# arthurpaulino :  42  repos
# LakshKD :  50  repos
# YanXiaobin-Ben :  251  repos
# EugeInzaugarat_twitter :  0  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# huiwenhan :  573  repos
# pduy :  16  repos
# Jonatha-Varjao :  31  repos
# koshal123 :  7  repos
# chengjingfeng :  2042  repos
# pakalagit :  1  repos
# JonathanReardon :  17  repos
# MohdNaved_twitter :  0  repos
# laifi :  3  repos
# viditkhemka63 :  32  repos
# emryslda :  4  repos
# aarna97pandey :  0  repos
# shrutikalra32_twitter :  0  repos
# brewkode :  48  repos
# akil101 :  0  repos
# gjogonzalezc :  52  repos
# martinoywa :  70  repos
# Rimab55 :  442  repos
# Sateesh110 :  49  repos
# gastonguillaux_twitter :  0  repos
# shubhsinha :  5  repos
# raghav-dalmia :  24  repos
# anderl80 :  19  repos
# lagvier :  128  repos
# adbernardi :  14  repos
# jensholm_gitlab :  0  repos
# aslisabanci :  40  repos
# harshit-py :  54  repos
# gstaxy :  14  repos
# epongpipat :  33  repos
# nagpalnitesh :  153  repos
# mridultuteja :  38  repos
# zzszmyf :  177  repos
# davft :  6  repos
# jerdra :  66  repos
# LuisFRoch :  37  repos
# NFWestland_twitter :  0  repos
# Freshia :  46  repos
# 0x6f736f646f :  65  repos
# sammyloto :  66  repos
# zhuofusong :  10  repos
# Pakigya :  72  repos
# torshind_gitlab :  0  repos
# blackzw :  28  repos
# jwoznicki :  19  repos
# PhillipHuang2017 :  14  repos
# robotliu327 :  0  repos
# prabhpreet332 :  29  repos
# Hemantr05 :  16  repos
# CoDeRgAnEsh :  0  repos
# dikshantj :  33  repos
# Cskarthik14_twitter :  0  repos
# vishu_rj_twitter :  0  repos
# nadimk1 :  2  repos
# mavlesreennap :  4  repos
# gsa245 :  6  repos
# Richard-mf :  51  repos
# pramodbutte :  3  repos
# gfournier :  22  repos
# Vai-bhav :  27  repos
# egalistmir :  26  repos
# Hudler :  3  repos
# jcusick13 :  22  repos
# calearning :  2  repos
# jlb226 :  37  repos
# Timsaur :  9  repos
# rsohlot :  371  repos
# Urmil.patel_gitlab :  0  repos
# ENM1989 :  6  repos
# prudhviraj9999 :  0  repos
# venkyyuvy :  13  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Majeriot :  86  repos
# sapawar4 :  12  repos
# pesobreiro :  44  repos
# EeroLihavainen_twitter :  0  repos
# bmahe_gitlab :  0  repos
# Emoruwa :  0  repos
# pandalearnstocode :  80  repos
# tekkamanmaverick :  3  repos
# jmeisele :  103  repos
# devbkhadka :  20  repos
# masip85 :  12  repos
# all4u1089 :  18  repos
# anbinhdtu :  0  repos
# martinagvilas :  44  repos
# SlivMus :  0  repos
# baitoeyWhoops :  1  repos
# willianfatec :  0  repos
# ensor01 :  1  repos
# harshit-2115 :  25  repos
# kailashahirwar :  11  repos
# erickjtorres :  18  repos
# akshayraichur :  40  repos
# mariamseao :  8  repos
# MrAE :  50  repos
# DavidWilla :  1  repos
# SauloFurtado :  12  repos
# kdeepak99 :  0  repos
# code-ninza :  0  repos
# arctrope_twitter :  0  repos
# benjamazzz :  26  repos
# FranciDona :  0  repos
# spbail :  42  repos
# arzoobh :  14  repos
# eugeniaft :  14  repos
# MohamedR_Yakoub_twitter :  0  repos
# fernlim :  7  repos
# 0x5f3759df_gitlab :  0  repos
# raj-priyanshu :  4  repos
# FritzPeleke :  4  repos
# enoch-sun :  0  repos
# nikitajare :  2  repos
# tumzera :  3  repos
# nikhilc3013 :  36  repos
# SyedMuhamadYasir :  3  repos
# AsifKha78660709_twitter :  0  repos
# anonymousr007 :  272  repos
# gansiorAL :  2  repos
# MasterBoBo :  11  repos
# motmoti :  3  repos
# basavyr :  105  repos
# marcmuon_gitlab :  0  repos
# monthol8th :  40  repos
# Anj-ali :  30  repos
# smyaknti :  38  repos
# paul_rietschka_twitter :  0  repos
# anshu_bansal280_twitter :  0  repos
# SiddHealth :  0  repos
# haiderny :  553  repos
# ermakoffivan_twitter :  0  repos
# Kinteshi :  10  repos
# angelaambroz :  32  repos
# davidyako_twitter :  0  repos
# Ratansingh648 :  38  repos
# smit-s :  20  repos
# jasjones82 :  0  repos
# alonsosilvaallende :  53  repos
# martynov1 :  0  repos
# enassalehali :  0  repos
# shiv-1998 :  1  repos
# kantaro1217 :  31  repos
# xun-tang :  6  repos
# dzekem :  15  repos
# umarakbar786 :  6  repos
# dbanerjee-io :  0  repos
# noppon_aim_gitlab :  0  repos
# Rohan641 :  0  repos
# mridul037 :  12  repos
# LiveWithCS :  6  repos
# lucyleeow :  41  repos
# yongddeng :  1  repos
# BenjaminBossan :  29  repos
# ThorbenJensen :  0  repos
# StephG2109 :  0  repos
# corriebar :  30  repos
# jorahn :  44  repos
# DatenBergwerker :  14  repos
# zioalex :  71  repos
# rachuri-anil :  27  repos
# Rubix982 :  217  repos
# veerlosar :  8  repos
# LuoTailong :  80  repos
# george2git :  0  repos
# dakotagrusak :  35  repos
# EveDong :  51  repos
# alexander-newton :  11  repos
# rajnish1642 :  8  repos
# mpilo24a :  18  repos
# emeti :  5  repos
# CarMiranda :  16  repos
# heyams :  7  repos
# PascalS86 :  23  repos
# ganeshraju :  67  repos
# sidneypaulymer :  4  repos
# matheusfrancisco :  67  repos
# DWFlanagan :  2  repos
# muqadir1 :  0  repos
# EricaXia :  22  repos
# chogg :  6  repos
# hunter-arch :  0  repos
# getachi :  5  repos
# poorna-kumar :  8  repos
# VaibhavSaraf :  73  repos
# LalliAcqua :  4  repos
# James-G-Hill :  21  repos
# ArthurBook :  8  repos
# norvan :  5  repos
# gbroccolo :  12  repos
# paoloturati :  2  repos
# melvincoding :  0  repos
# anjumuaf123_twitter :  0  repos
# AminTR :  1  repos
# THElysian :  0  repos
# justisvas_twitter :  0  repos
# h45h3m :  1  repos
# aerilashraf_twitter :  0  repos
# arturgvieira_twitter :  0  repos
# Kevinelectronics :  9  repos
# eliseo :  4  repos
# whimian :  54  repos
# DiamondKesha :  3  repos
# dannyng1988 :  2  repos
# sennierer :  37  repos
# pinemosquito :  15  repos
# subhash-shah :  30  repos
# chekoduadarsh :  38  repos
# Akuseru1 :  0  repos
# nickyfoto :  24  repos
# jasonbytes_twitter :  0  repos
# tanmay1618 :  25  repos
# vivekkumar2696 :  17  repos
# cleverxiaoming :  0  repos
# jonggan-kim :  85  repos
# nikhil6041 :  15  repos
# kpiyush04 :  50  repos
# kingzley :  7  repos
# doclockh :  0  repos
# tirthasheshpatel :  72  repos
# srbhr :  108  repos
# sridhar514 :  0  repos
# raybellwaves :  180  repos
# xadupre :  32  repos
# ketanmehta :  20  repos
# Rishit-dagli :  74  repos
# BonitaTerror :  12  repos
# duskotovilovic :  0  repos
# Anthony-Duan :  0  repos
# mahismpatil :  1  repos
# nathamsr11 :  31  repos
# mizukirc :  9  repos
# kckusal :  35  repos
# Sam-XGen :  14  repos
# TechMaster254 :  4  repos
# nehargupta :  15  repos
# albertopiva :  0  repos
# WildandArt :  23  repos
# nthu9280 :  44  repos
# 33eyes :  42  repos
# miwojc :  76  repos
# forestchen1224 :  12  repos
# csj4032 :  47  repos
# TakshPanchal :  28  repos
# vccdevteam_gitlab :  0  repos
# josepacelli :  10  repos
# SandeepAswathnarayana :  22  repos
# ScottHameed_twitter :  0  repos
# prithivirajka :  8  repos
# Siddhant-K-code :  264  repos
# 405Found_gitlab :  0  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# cemeiq :  225  repos
# greatsharma :  64  repos
# hansenallison :  11  repos
# RuKrei :  73  repos
# hhnnhh :  16  repos
# lucasmarinsnave :  7  repos
# sammsc :  3  repos
# ryotan17 :  11  repos
# anaisabeldhero :  6  repos
# fabi-cast :  18  repos
# noatamir :  20  repos
# wbadiah_gitlab :  0  repos
# JanSos_gitlab :  0  repos
# avimiller :  3  repos
# chbrandt :  118  repos
# DatenBiene :  17  repos
# Batalex :  10  repos
# hs-nazuna :  7  repos
# philcor123 :  1  repos
# itsalitee :  0  repos
# ARJUNRAGHUNANDANAN :  14  repos
# danielgil1 :  88  repos
# ifor :  2  repos
# bhanu566 :  19  repos
# 6arash6 :  7  repos
# adriangb :  107  repos
# reddyprasade :  85  repos
# eldaware0 :  1  repos
# hassanmehmud :  12  repos
# rohanishervin :  0  repos
# AndreasTraut :  12  repos
# prometheusred :  4  repos
# NJonesUK :  31  repos
# onriv :  49  repos
# Julia_Namanka_twitter :  0  repos
# WRMowrey_twitter :  0  repos
# shengnoah :  27  repos
# TobisLee :  11  repos
# SumanjaliDamarla :  28  repos
# ChipChap1_gitlab :  0  repos
# MrAsimZahid :  77  repos
# SinghSamrendra :  0  repos
# yetudada :  19  repos
# gbolmier :  10  repos
# victordinofb_twitter :  0  repos
# quanduoling :  18  repos
# cdkfox :  0  repos
# 181149 :  38  repos
# roncecchini :  0  repos
# TusharPune :  4  repos
# Kathir7893 :  14  repos
# vendrafilm :  0  repos
# sugatoray :  153  repos
# OJASH04 :  35  repos
# novice-coder :  7  repos
# ccdevcreative :  4  repos
# 0az :  107  repos
# CorentinPa :  3  repos
# AssassinTee :  34  repos
# nulpern_gitlab :  0  repos
# tkoyama010 :  284  repos
# rmenke_gitlab :  0  repos
# Prahitha :  28  repos
# phanigithub :  26  repos
# mounalahrach :  2  repos
# oxssa :  1  repos
# ajeema :  62  repos
# mowhamadrexa :  0  repos
# ianmcoffey_twitter :  0  repos
# winkidzz :  4  repos
# marenwestermann :  16  repos
# rivergold :  37  repos
# GeorMurk :  53  repos
# dantepawn :  22  repos
# aficionadoai :  29  repos
# MOtweetsMOProbs_twitter :  0  repos
# Motanovici :  16  repos
# glenbhermon_twitter :  0  repos
# aliisakroe :  20  repos
# sushruthkumar :  1  repos
# eagleware :  5  repos
# n30sh4d0wderp_twitter :  0  repos
# stormstone :  10  repos
# jameshphillips :  3  repos
# vlandeiro :  23  repos
# JohnPaulMSU15_twitter :  0  repos
# khushwantkodecha :  72  repos
# Arturocdb10_twitter :  0  repos
# takashi-matsushita :  3  repos
# ibanmarco_gitlab :  0  repos
# laranea :  1474  repos
# kblaisdell_gitlab :  0  repos
# jjaskirat :  22  repos
# g4brielvs_twitter :  0  repos
# Dgomzi :  5  repos
# Cybermise :  0  repos
# boedybios :  22  repos
# NobleEdu786 :  3  repos
# hamdiazhari_gitlab :  0  repos
# Jean_DeCarli_twitter :  0  repos
# jyusnu :  3  repos
# YaseenMd22 :  2  repos
# tserre :  5  repos
# scaomath :  49  repos
# rojesh-shikhrakar :  24  repos
# egbay :  10  repos
# Alphagoal1_twitter :  0  repos
# nathantnorth_gitlab :  0  repos
# ChipKerchner :  6  repos
# Vasuji :  28  repos
# Bri9k_gitlab :  0  repos
# kindkindk :  18  repos
# FrancisBilla :  93  repos
# Rajatkhatri7 :  61  repos
# rajkumarGH :  6  repos
# ankitgera24 :  4  repos
# Shivammishra18 :  1  repos
# JosephTLucas :  16  repos
# gabrielbhl :  27  repos
# deltasun_gitlab :  0  repos
# dogancanbakir :  4  repos
# ayushvidushi01_gitlab :  0  repos
# veeravignesh1 :  27  repos
# AshutoshVarma04 :  5  repos
# _slyn_twitter :  0  repos
# HarryPotterRon :  0  repos
# tinhng_twitter :  0  repos
# VivanVatsa :  268  repos
# darkjhesus :  0  repos
# SulemanRasheed :  13  repos
# MakotoUchida :  8  repos
# youssefabdelm_twitter :  0  repos
# eeeclipse :  40  repos
# Anil-Solasa :  0  repos
# ravi99609680_twitter :  0  repos
# ammarchalifah :  17  repos
# benoitdescamps :  22  repos
# PbChauhan :  13  repos
# niazangels :  65  repos
# yagi-3 :  3  repos
# austospumanto :  20  repos
# OsipovOleg :  12  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# michellemroy :  12  repos
# happyxyl :  5  repos
# jaymehta1907 :  0  repos
# leisir966 :  19  repos
# developerbuilds :  0  repos
# C4rst3n :  0  repos
# evonnec :  7  repos
# AbrahamReuben :  5  repos
# shresth2102001 :  28  repos
# imtejagst_gitlab :  0  repos
# amy12xx :  28  repos
# alanlujan91 :  28  repos
# DataPointChris :  43  repos
# rithvikrao :  13  repos
# rubywerman :  26  repos
# parthivc :  15  repos
# joshuacwnewton :  17  repos
# krfla :  1  repos
# vphacker :  58  repos
# arakotoz :  15  repos
# bbgw_gitlab :  0  repos
# mdarwinj382000 :  10  repos
# Beau-Yang :  3  repos
# d3b0unce :  0  repos
# ManelDjehiche :  14  repos
# Borschevik :  11  repos
# DanielAtKrypton :  46  repos
# haianhnt.st_gitlab :  0  repos
# Prasannadhungel4 :  9  repos
# robertoramsis :  1  repos
# aicampg :  9  repos
# _00r2_twitter :  0  repos
# bfiranski :  0  repos
# chaitanyamogal :  22  repos
# Huzaib :  41  repos
# kldavis52 :  14  repos
# Luberr-Dhruv :  0  repos
# asnramos :  290  repos
# bmaisonn :  19  repos
# abdoulayegk :  76  repos
# eastSpawn :  3  repos
# vvieira22 :  12  repos
# graemenail_gitlab :  0  repos
# hassanjaved_twitter :  0  repos
# sadakmed :  34  repos
# edipretoro :  81  repos
# hfox_twitter :  0  repos
# avats-dev :  63  repos
# CoderJeel :  9  repos
# blayz3r :  13  repos
# felix-hilden :  14  repos
# CRBelhekar :  17  repos
# nha6ki :  43  repos
# aman5319 :  41  repos
# freddyaboulton :  36  repos
# PankajS81824284_twitter :  0  repos
# batfolx :  37  repos
# lw4c_gitlab :  0  repos
# phmonforte :  4  repos
# xiaoye-hua :  29  repos
# yajinwuzl :  80  repos
# BTDevelop :  178  repos
# RamyaNP :  16  repos
# Arkreactor99 :  2  repos
# kpizmax_twitter :  0  repos
# singhsanidhya :  0  repos
# nursyah21 :  17  repos
# fransim24 :  1  repos
# sachindev1111 :  3  repos
# killercode_gitlab :  0  repos
# alanktwong_gitlab :  0  repos
# csinva :  52  repos
# umeshchaturvedi :  9  repos
# vipulgarg1 :  17  repos
# jenniferjang :  4  repos
# Masud034 :  22  repos
# vanyusuf1 :  44  repos
# flarsu :  25  repos
# AdicherlaVenkataSai :  33  repos
# seanstappas :  22  repos
# EugeneWeng_gitlab :  0  repos
# gennadylaptev :  13  repos
# MattDivers :  1  repos
# yingjie668 :  1  repos
# trushilpatel9898_gitlab :  0  repos
# krishnasrihari_gitlab :  0  repos
# yashasvimisra2798 :  63  repos
# godzzo :  58  repos
# itsAPK :  18  repos
# trianglewavvve :  12  repos
# madyanki_twitter :  0  repos
# arvindkumarc :  43  repos
# ItsmeKernel :  5  repos
# kushaangupta :  27  repos
# kobibarhanin :  36  repos
# whitefoxx :  22  repos
# Ashindustry007 :  16  repos
# Samuel-Akinyemi :  7  repos
# anantgna :  3  repos
# viraj1596 :  15  repos
# arabhiar :  17  repos
# axtitv :  0  repos
# siaocing-liou :  26  repos
# fariaseduv :  4  repos
# IshantKukreti_twitter :  0  repos
# felixdittrich92 :  49  repos
# Bcromas :  18  repos
# dinaklal :  35  repos
# JoshuaH51361535_twitter :  0  repos
# alien1403 :  26  repos
# ivijai :  5  repos
# sJakovac :  5  repos
# Davidj361 :  22  repos
# jeedo_gitlab :  0  repos
# DingXiangYuanZhiXing :  0  repos
# singhomics :  1  repos
# peterzcy :  2  repos
# vivaswanraju :  0  repos
# pavansai26 :  195  repos
# ichisadashioko :  213  repos
# pruthvishetty :  155  repos
# AjeelAhmed1998 :  22  repos
# Rao-Ahsan :  4  repos
# Abbas-Tewfiq :  1  repos
# asdhjkg :  0  repos
# byo-ai :  166  repos
# jay_kim07_twitter :  0  repos
# GhostUser :  49  repos
# xmag19 :  0  repos
# lode-runner :  8  repos
# kwishna :  49  repos
# elvinaqa :  127  repos
# niraj876 :  20  repos
# chandan5362 :  37  repos
# AllenZYJ :  27  repos
# salih.four_gitlab :  0  repos
# UhakeR :  19  repos
# dolanskurd :  0  repos
# anilkumarKanasani :  2  repos
# allmwh :  22  repos
# krivicydocky :  10  repos
# mokeddembillel :  25  repos
# CoMartel :  10  repos
# SC188 :  0  repos
# shubhraneel :  27  repos
# Yahyakiani :  15  repos
# immeelamit_twitter :  0  repos
# cpmakwana28 :  11  repos
# adnahmed :  10  repos
# vsedov :  52  repos
# roumenguha :  17  repos
# Newbie-Coder-1105 :  9  repos
# hocnx :  7  repos
# RAVANv2 :  27  repos
# giuliolovisotto :  16  repos
# roma_glushko_twitter :  0  repos
# festusdrakon :  35  repos
# Ruchikamodgil :  25  repos
# yazabat :  64  repos
# ashishagrawal121 :  8  repos
# AdityaPujara23 :  7  repos
# mangeshh :  19  repos
# hemansnation :  53  repos
# EmilMachine :  18  repos
# NoleWang :  8  repos
# abhinavsri05 :  2  repos
# ArtificialEdge_gitlab :  0  repos
# amannayak :  25  repos
# SultanOrazbayev :  40  repos
# annajiat :  397  repos
# SeriousFun01 :  5  repos
# Hafsah2020 :  45  repos
# veronikaro :  17  repos
# gatto :  5  repos
# SurajUpadhyay0_twitter :  0  repos
# azihna :  11  repos
# issam9 :  17  repos
# hudsonmendes :  17  repos
# designer1234 :  0  repos
# ratulalahy :  30  repos
# antonyrp :  0  repos
# oljfte :  6  repos
# halsawadi :  27  repos
# cliffordEmmanuel :  30  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# saxonaique :  8  repos
# lengstrom :  134  repos
# isaack-mungui :  30  repos
# madhukumble :  38  repos
# KylevdLangemheen :  6  repos
# misskecupbung :  107  repos
# hoodmane :  63  repos
# Adongo :  9  repos
# ubiest :  7  repos
# KSANTHOSH200 :  54  repos
# anjal-amin :  0  repos
# sergioCocodrilo :  15  repos
# sharyar :  30  repos
# tommasodelorenzo :  2  repos
# jamesbsilva :  23  repos
# SmellySalami :  11  repos
# que-vector :  22  repos
# avaish1409 :  16  repos
# leonardojimenez1990 :  6  repos
# tobinngo :  4  repos
# lnclt :  4  repos
# carolinehaoud :  1  repos
# CrazyDry :  10  repos
# ShubhamUnique :  1  repos
# GitHiru :  0  repos
# AlexIoannides :  21  repos
# matheuscscampos :  6  repos
# amal-khailtash :  17  repos
# nmcardoso :  62  repos
# MojtabaMoodi_gitlab :  0  repos
# lester1027 :  9  repos
# karthy257 :  422  repos
# iacopoff :  12  repos
# amoyrand :  0  repos
# TyagiSumit :  1  repos
# AndyTrento_twitter :  0  repos
# natecrisler :  172  repos
# jaogye_twitter :  0  repos
# savitha91 :  16  repos
# MAT919 :  14  repos
# teeneewilliams :  13  repos
# charithmadhuranga :  2426  repos
# ChrisE1979_gitlab :  0  repos
# narsiis23 :  5  repos
# kslader8 :  11  repos
# irsayvid :  53  repos
# hoangnt2601 :  23  repos
# vikashyadav730 :  30  repos
# akinyosoyeisaac :  28  repos
# RomajiQuadhash :  2  repos
# limtete :  17  repos
# legitishan :  33  repos
# TanvirFahimBD :  21  repos
# unboundval :  0  repos
# mnTusi_gitlab :  0  repos
# kjanko :  18  repos
# Akashtp :  10  repos
# pramjan90 :  8  repos
# golubitsky :  47  repos
# Lisakestens :  3  repos
# Hebbiatester23 :  0  repos
# AlphaQuantCoder :  0  repos
# Barrick-San :  3  repos
# temmyzeus :  65  repos
# ZhengzeZhou :  13  repos
# zoeprieto_twitter :  0  repos
# ibeglab :  1  repos
# MichaelBroox :  240  repos
# kitmonisit :  37  repos
# santosh24x7 :  1  repos
# scott-astatine :  10  repos
# nishigami-0 :  0  repos
# priyanshi-tyagi :  9  repos
# huynhvuh :  44  repos
# vaishnavipatil4848 :  5  repos
# hardRockWorld :  4  repos
# CRYPTOcoderAS :  63  repos
# Anandh003 :  18  repos
# gabrielblancogarcia :  40  repos
# weirdfish23 :  12  repos
# karen-pal :  67  repos
# stimils2 :  22  repos
# Stanimir-Ivanov :  9  repos
# um_duaa123_twitter :  0  repos
# __jrgjon___twitter :  0  repos
# alceballosa :  26  repos
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# Reach limit! Sleep  600  seconds!
# sofide :  46  repos
# ninjakira :  11  repos
# jeferrodrigu :  5  repos
# will-rice :  97  repos
# zoj613 :  19  repos
# kubendra :  0  repos
# jchaconm :  41  repos
# leonardorocc0 :  3  repos
# acharya_aditya_mi_gitlab :  0  repos
# sinasajadpour :  1  repos
# Vigneshwaren :  6  repos
# EdwardTheLegend :  20  repos
# cwindolf :  38  repos
# SaurabhTripathi62 :  35  repos
# yusukekyokawa :  76  repos
# bobbykawade :  43  repos
# hsuehkuan-lu :  35  repos
# Aura09c :  1  repos
# Ana16sak :  10  repos
# tejaswivg :  11  repos
# linnforsman :  28  repos
# whitewizard-debug :  1  repos
# Anmoldeep5056 :  2  repos
# irogi :  5  repos
# adluinf :  9  repos
# KiranHipparagi :  23  repos
# fathimhiri :  40  repos
# BradAF :  6  repos
# Bhavya1705 :  15  repos
# a-poor :  216  repos
# dongr0510 :  18  repos
# vincentAgnus :  33  repos
# jessauckland_twitter :  0  repos
# birane012 :  6  repos
# NoahWoehler_twitter :  0  repos
# makingglitches :  11  repos
# MichaelShoemaker :  26  repos
# PatrikWagnerUK :  16  repos
# bikashkarmokar :  21  repos
# lobpcg :  5  repos
# o-diegolopes :  9  repos
# metinuslu :  61  repos
# jgiera :  2  repos
# Burnleydev1 :  55  repos
# ericabrauer :  12  repos
# chritter :  87  repos
# BerylKanali :  16  repos
# ImminentFlair_gitlab :  0  repos
# jaysharma_gitlab :  0  repos
# apurvsibal :  59  repos
# keenan.thomas_gitlab :  0  repos
# etroncrypto_twitter :  0  repos
# aufarkari :  5  repos
# Akanichi :  9  repos
# jay-chakalasiya :  39  repos
# gpablo6 :  8  repos
# bobde_yagyesh_twitter :  0  repos
# MohamedBsh :  10  repos
# hakanceran64 :  10  repos
# adib-enc :  57  repos
# LEVI-OAQ :  8  repos
# chrisgoddard :  41  repos
# beckerfuffle_gitlab :  0  repos
# VOLCANIC-9 :  2  repos
# Epsilon01 :  28  repos
# CaoMinhTin15_twitter :  0  repos
# ArthDh :  45  repos
# mirroredcube :  1  repos
# ojeda-e :  24  repos
# akhilkathi97 :  15  repos
# soma2000-lang :  219  repos
# laurburke :  24  repos
# GulsahDeger :  0  repos
# AChand20 :  19  repos
# MikuAndRabbit :  5  repos
# Scott-Collier :  3  repos
# erkanmalcokcom_twitter :  0  repos
# stac-bot :  18  repos
# aditya172926 :  43  repos
# aytekine2 :  4  repos
# somexgupta :  22  repos
# iraquitan_filho_twitter :  0  repos
# Ali-1329 :  14  repos
# purna135 :  83  repos
# Ramanand-Yadav :  34  repos
# areyouanti :  0  repos
# simona-mircheva :  13  repos
# vish-321 :  22  repos
# mkuchhal :  45  repos
# bprasad26 :  38  repos
# francoisgoupil :  9  repos
# sanlukuangji :  9  repos
# charanjaka :  5  repos
# AnkitKumar2698 :  0  repos
# himanshu1856 :  1  repos
# Dev514 :  20  repos
# earlev4 :  0  repos
# GauravChoudhay :  19  repos
# shayanbahrampour :  14  repos
# Shubham1450 :  3  repos
# 0xShervin :  8  repos
# moe-a-m_gitlab :  0  repos
# mozoraineer :  1  repos
# marsnut :  19  repos
# ctc-er :  1  repos
# luigidamico100 :  8  repos
# austinvas_gitlab :  0  repos
# doriane.ajmi_gitlab :  0  repos
# Args0212 :  2  repos
# Diwakar-Gupta :  40  repos
# Klas96 :  22  repos
# ShanDeng123 :  10  repos
# mrcreamio :  64  repos
# dany-gaga :  3  repos
# abypranata :  0  repos
# fkucuker___twitter :  0  repos
# miverone :  0  repos
# mehrdadmoradii :  11  repos
# srthiru :  11  repos
# gkanapathy :  15  repos
# devkaranjoshi :  16  repos
# GitterDeb :  0  repos
# cristianovianto_twitter :  0  repos
# aaaaa-ch :  0  repos
# soumenganguly :  63  repos
# ymzayek :  10  repos
# Squidgi :  2  repos
# iamarunbrahma :  10  repos
# jgutierrezre :  6  repos
# hasninemirja :  20  repos
# devnev39 :  25  repos
# AlexBSX_gitlab :  0  repos
# aleksandernitka :  37  repos
# haochunchang :  21  repos
# oshiteku :  16  repos
# DylanLIiii :  10  repos
# Chsong98255117_twitter :  0  repos
# kimmi1206 :  51  repos
# mmelnicki :  1  repos
# FourFortyFour :  4  repos
# gjftta :  2  repos
# sonavaneashish33_gitlab :  0  repos
# energysystems2022 :  0  repos
# sirbobthemarvelous :  13  repos
# j-imsa :  4  repos
# adam-grant-hendry :  11  repos
# lhhhhhhappy :  0  repos
# mazinalmosawy :  1  repos
# IvanLauLinTiong :  32  repos

# %%
len(users_not_found)
# Out:
# 791

# %%
with open(Gitter_folder+channel1+'_nofile.txt', 'w') as fp:
    for item in users_not_found:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %% [markdown]
# ## User metadata

# %%
import pandas as pd
import numpy as np

# %%
user_files = os.listdir(GitHub_folder)

# %%
names= []
repos=[]
languages = []
topics=[]

# %%
for username in usernames:
    username = username.strip()
    if os.path.exists(GitHub_folder+username+'.json') == False:
        continue
    
    names.append(username)
    with open(GitHub_folder+username+'.json', 'r') as f:
        data = json.load(f)
        lang = set()
        topic = set()
        repos.append(len(data))
        
        for num in range(len(data)):
            lang.update(lang,data[num]["language"])
            topic.update(topic,data[num]["topics"])
            
        languages.append(list(lang))
        topics.append(list(topic))

# %%
df = pd.DataFrame()

# %%
df["User"] = names
df["Repo_num"] = repos
df["Repo_languages"] = languages
df["Repo_topics"] = topics

# %%
df.head(10)
# Out:
#             User  Repo_num                                     Repo_languages  \
# 0      jiteshk23         5  [TeX, JavaScript, CSS, Dockerfile, Python, Jup...
# 1   RahulKulhari        27  [Objective-C, Python, Batchfile, HTML, Groff, ...
# 2         jaepil        37  [SWIG, Objective-C, Groovy, PLSQL, FreeMarker,...
# 3       edwinksl        75  [Objective-C, Python, AutoHotkey, Batchfile, H...
# 4   linhmtran168        97  [Go, Erlang, Python, Batchfile, HTML, CSS, PHP...
# 5          rishy        49  [Groovy, Python, Batchfile, HTML, Groff, Power...
# 6      MechCoder        98  [PLpgSQL, FreeMarker, Python, Batchfile, HTML,...
# 7   mastergenius        13  [ActionScript, Java, Mako, Objective-C, Shell,...
# 8       sirinath       170  [Go, Standard ML, Objective-C, PLpgSQL, Groovy...
# 9  invinciblejha       241  [Objective-C, Python, C#, Batchfile, Gnuplot, ...
#
#                                          Repo_topics
# 0  [terminal, jupyter, pca, unsupervised-learning...
# 1                                                 []
# 2                                                 []
# 3  [batteries, code-review, stackexchange, julia,...
# 4                                                 []
# 5                                                 []
# 6                          [music-generation, audio]
# 7                                                 []
# 8                                                 []
# 9                                                 []

# %%
df.describe()
# Out:
#           Repo_num
# count  3527.000000
# mean     53.253473
# std     136.351739
# min       1.000000
# 25%      10.000000
# 50%      24.000000
# 75%      52.000000
# max    2852.000000

# %%
df.to_csv(Gitter_folder+channel1+'_meta.csv', index=False)

# %%
filenames = glob.glob(r"C:/Users/wangs/Desktop/Test/*ascii*")

# %%
filenames
# Out:
# ['C:/Users/wangs/Desktop/Test\\Data_ScikitLearn.ascii.txt']
