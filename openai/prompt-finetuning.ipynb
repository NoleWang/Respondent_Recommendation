# %% [markdown]
# <span style="color:orange; font-weight:bold">Note: To answer questions based on text documents, we recommend the procedure in <a href="https://github.com/openai/openai-cookbook/blob/main/examples/Question_answering_using_embeddings.ipynb">Question Answering using Embeddings</a>. Some of the code below may rely on <a href="https://github.com/openai/openai-cookbook/tree/main/transition_guides_for_deprecated_API_endpoints">deprecated API endpoints</a>.</span>

# %% [markdown]
# # 3. Train a fine-tuning model specialized for Q&A
# This notebook will utilize the dataset of context, question and answer pairs to additionally create adversarial questions and context pairs, where the question was not generated on that context. In those cases the model will be prompted to answer "No sufficient context for answering the question". We will also train a discriminator model, which predicts whether the question can be answered based on the context or not.
#
# We will add hard adversarial examples as well, which will be based either on semantically similar sections, or neighbouring sections, originating from the same article.

# %%
import openai
import tiktoken
import os
import pandas as pd
import numpy as np
import time

# %%
df = pd.read_csv('../Data/chat_pattern/chat_test_missing_1000.csv',encoding='iso-8859-1')
df.fillna("N",inplace=True)
df
# Out:
#              source                                              issue
# 0           angular  Hi, when I am trying to apply class dynamicall...  \
# 1           angular  is it possible to get a RouteConfig matched ag...
# 2           angular  I have angular running from a .Net Core server...
# 3           angular  Hello everyone, I want to do sub menu with sea...
# 4           angular  I'm struggling with getting this logic\n      ...
# ..              ...                                                ...
# 995          appium  Hello Can we run automation scripts with signe...
# 996  deeplearning4j  Hi, I am trying to move to 3.9, but it seems t...
# 997         angular  Hi, I'm new to angular and I'm trying to integ...
# 998         angular  I have a service X that currently is scoped to...
# 999         angular  Hi guys, hope you're all doing good :) In my a...
#
#                                            issue_clean
# 0    Hi, when I am trying to apply class dynamicall...  \
# 1    is it possible to get a RouteConfig matched ag...
# 2    I have angular running from a .Net Core server...
# 3    Hello everyone, I want to do sub menu with sea...
# 4    I'm struggling with getting this logic [code]....
# ..                                                 ...
# 995  Hello Can we run automation scripts with signe...
# 996  Hi, I am trying to move to 3.9, but it seems t...
# 997  Hi, I'm new to angular and I'm trying to integ...
# 998  I have a service X that currently is scoped to...
# 999  Hi guys, hope you're all doing good :) In my a...
#
#                                                PS_sent
# 0    T2: it is messing up my material css i.e I am ...  \
# 1                                                    N
# 2    T1: The server won't even load the app (by des...
# 3                  T2: but  i have problem in sub menu
# 4           T1: I'm struggling with getting this logic
# ..                                                 ...
# 995                                                  N
# 996                                                  N
# 997                                                  N
# 998                                                  N
# 999                                                  N
#
#                                         predicted_PS
# 0    PS_NEG_VERB,PS_NEG_AUX_ADV_ADJ,PS_NEG_AUX_VERB,  \
# 1                                                  N
# 2                                   PS_NEG_AUX_VERB,
# 3                                        PS_PROBLEM,
# 4                          PS_STRUGGLING,PS_VERB_NO,
# ..                                               ...
# 995                                     PS_NEG_VERB,
# 996   PS_NEG_AUX_VERB,PS_NEG_AUX_ADV_ADJ,PS_ETD_TRY,
# 997                    PS_VERB_ERROR,PS_NEG_ADV_ADJ,
# 998                   PS_NEG_AUX_ADV_ADJ,PS_ETD_TRY,
# 999                                                N
#
#                                               ETD_sent
# 0    T1: when I am trying to apply class dynamicall...  \
# 1    T1: I'm trying to create a Breadcrumb componen...
# 2    What's the best way for the angular app to get...
# 3    T1: I want to do sub menu with searh like in g...
# 4    T2: I wanted to set a default value to the dro...
# ..                                                 ...
# 995                                                  N
# 996                                                  N
# 997                                                  N
# 998                                                  N
# 999                            and how to prevent this
#
#                                         predicted_ETD  y_PS  y'_PS  Acc_PS
# 0                                      ETD_TRYING_TO,     0      0       1  \
# 1    ETD_BE_POSSIBLE_TO,ETD_TRYING_TO,ETD_WOULD_LIKE,     1      1       1
# 2                                                   N     0      0       1
# 3                       ETD_WANT_TO,ETD_CAN_QUESTION,     0      0       1
# 4                                        ETD_WANT_TO,     0      0       1
# ..                                                ...   ...    ...     ...
# 995                                 ETD_CAN_QUESTION,     0      0       1
# 996                                    ETD_TRYING_TO,     0      0       1
# 997                                    ETD_TRYING_TO,     0      0       1
# 998   ETD_NEED_TO,ETD_IS_THERE_QUESTION,ETD_WOULD_BE,     0      0       1
# 999                                         ETD_HOPE,     0      1       0
#
#      ...  Acc_ETD                                          openAI_PS
# 0    ...        1  The sentence """ it is messing up my material ...  \
# 1    ...        1               No patterns found. The answer is NO.
# 2    ...        0               No patterns found. The answer is NO.
# 3    ...        1  The sentence """ i have problem in sub menu wi...
# 4    ...        1  The sentence "I'm struggling with getting this...
# ..   ...      ...                                                ...
# 995  ...        1                                                  N
# 996  ...        1                                                  N
# 997  ...        1                                                  N
# 998  ...        1                                                  N
# 999  ...        1                                                  N
#
#                Inferred_PS_pattern y''_PS ACC_AI_PS
# 0                      PS_NEG_VERB    1.0       0.0  \
# 1                                N    0.0       0.0
# 2                                N    0.0       1.0
# 3    "problem" is the [error-term]    1.0       0.0
# 4                                N    1.0       0.0
# ..                             ...    ...       ...
# 995                              N      N         N
# 996                              N      N         N
# 997                              N      N         N
# 998                              N      N         N
# 999                              N      N         N
#
#                                             openAI_ETD Inferred_ETD_pattern
# 0    The sentence """ when I am trying to apply cla...                    N  \
# 1    The sentence """ I'm trying to create a Breadc...                    N
# 2    The sentence """ What's the best way for the a...                  new
# 3    The sentence "i have problem in sub menu with ...                  new
# 4    The sentence """I wanted to set a default valu...                    N
# ..                                                 ...                  ...
# 995                                                  N                    N
# 996                                                  N                    N
# 997                                                  N                    N
# 998                                                  N                    N
# 999                                                  N                    N
#
#     coment y''_ETD ACC_AI_ETD
# 0        N     1.0        0.0
# 1        N     1.0        0.0
# 2        N     1.0        0.0
# 3        N     1.0        0.0
# 4        N     1.0        0.0
# ..     ...     ...        ...
# 995      N       N          N
# 996      N       N          N
# 997      N       N          N
# 998      N       N          N
# 999      N       N          N
#
# [1000 rows x 22 columns]

# %% [markdown]
# Split the sections into a training and testing set

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(df, test_size=0.1, random_state=42)
train_df, test_df = train_test_split(train_df, test_size=1/9, random_state=42)
len(train_df), len(val_df), len(test_df)
# Out:
# (800, 100, 100)

# %%
test_df
# Out:
#              source                                              issue
# 361          docker  Im trying to replace my brew docker instance w...  \
# 91          angular  howdee. i'm the fool use case who doesn't unde...
# 311          docker  Is there a way to force docker to exit on SIGT...
# 253          nodejs  Hi guys. I desperately need help with project ...
# 72          angular  Could someone give me an example on stackblitz...
# ..              ...                                                ...
# 870          appium  Has anyone seen the error :'Error: Cannot find...
# 254  deeplearning4j  AlexDBlack: is there an example of how to use ...
# 935      typescript  I guess I get to become a node developer. What...
# 415          appium  How to launch IOS 10 native apps using appium ...
# 779          gitter  Hi, im on linux - ubuntu. I like the feature w...
#
#                                            issue_clean
# 361  Im trying to replace my brew docker instance w...  \
# 91   howdee. i'm the fool use case who doesn't unde...
# 311  Is there a way to force docker to exit on SIGT...
# 253  Hi guys. I desperately need help with project ...
# 72   Could someone give me an example on stackblitz...
# ..                                                 ...
# 870  Has anyone seen the error :'Error: Cannot find...
# 254  AlexDBlack: is there an example of how to use ...
# 935  I guess I get to become a node developer. What...
# 415  How to launch IOS 10 native apps using appium ...
# 779  Hi, im on linux - ubuntu. I like the feature w...
#
#                                                PS_sent
# 361                                                  N  \
# 91   T1: i'm the fool use case who doesn't understa...
# 311                                                  N
# 253                                                  N
# 72   T1: but so far, in the consumer application, c...
# ..                                                 ...
# 870                                                  N
# 254                                                  N
# 935                                                  N
# 415                                                  N
# 779                                                  N
#
#                                           predicted_PS
# 361            PS_NEG_AUX_VERB,PS_NEG_VERB,PS_ETD_TRY,  \
# 91      PS_NEG_AUX_VERB,PS_NEG_AUX_ADV_ADJ,PS_ETD_TRY,
# 311  PS_NEG_AUX_VERB,PS_NEG_ADV_ADJ,PS_PROBLEM_IS,P...
# 253                         PS_VERB_ERROR,PS_NEG_VERB,
# 72                                    PS_NEG_AUX_VERB,
# ..                                                 ...
# 870  PS_VERB_ERROR,PS_NEG_AUX_VERB,PS_ERROR_NOUN_PH...
# 254                                   PS_NEG_AUX_VERB,
# 935                                                  N
# 415                                                  N
# 779                          PS_VERB_ERROR,PS_PROBLEM,
#
#                                               ETD_sent
# 361                                                  N  \
# 91   T2: the use case is i want to write not a full...
# 311                                                  N
# 253                                                  N
# 72   how I can make source maps of a compiled angul...
# ..                                                 ...
# 870                                                  N
# 254                                                  N
# 935                                                  N
# 415  How to launch IOS 10 native apps using appium ...
# 779                                                  N
#
#                                          predicted_ETD  y_PS  y'_PS  Acc_PS
# 361                                     ETD_TRYING_TO,     0      0       1  \
# 91                            ETD_USED_TO,ETD_WANT_TO,     0      0       1
# 311  ETD_INSTEAD_OF_EXP_BEHAVIOR,ETD_IS_THERE_QUEST...     0      0       1
# 253                                                  N     0      0       1
# 72                                                   N     0      0       1
# ..                                                 ...   ...    ...     ...
# 870                                                  N     0      0       1
# 254                                                  N     0      0       1
# 935                                     ETD_IMPLEMENT,     1      1       1
# 415                                                  N     1      1       1
# 779                                                  N     1      0       0
#
#      ...  Acc_ETD                                          openAI_PS
# 361  ...        1                                                  N  \
# 91   ...        1  The sentence """ i'm the fool use case who doe...
# 311  ...        1                                                  N
# 253  ...        0                                                  N
# 72   ...        0  The sentence "I enabled sourceMap's vendor pro...
# ..   ...      ...                                                ...
# 870  ...        0                                                  N
# 254  ...        0                                                  N
# 935  ...        1                                                  N
# 415  ...        0                                                  N
# 779  ...        0                                                  N
#
#      Inferred_PS_pattern y''_PS ACC_AI_PS
# 361                    N      N         N  \
# 91                     N    1.0       0.0
# 311                    N      N         N
# 253                    N      N         N
# 72                   new    1.0       0.0
# ..                   ...    ...       ...
# 870                    N      N         N
# 254                    N      N         N
# 935                    N      N         N
# 415                    N      N         N
# 779                    N      N         N
#
#                                             openAI_ETD   Inferred_ETD_pattern
# 361  The sentence """ when i try and access it on t...          ETD_TRYING_TO  \
# 91   The sentence """ i want to write not a full an...                      N
# 311  The sentence """ Is there a way to force docke...  ETD_IS_THERE_QUESTION
# 253  The sentence """ I desperately need help with ...                    new
# 72   The sentence """ I enabled sourceMap's vendor ...                    new
# ..                                                 ...                    ...
# 870                                                  N                      N
# 254  The sentence """ Can't find any in the example...                    low
# 935                                                  N                      N
# 415                                                  N                      N
# 779                                                  N                      N
#
#                             coment y''_ETD ACC_AI_ETD
# 361                              N     1.0        0.0
# 91                               N     1.0        0.0
# 311                              N     1.0        0.0
# 253  need help with NN that has NN     1.0        0.0
# 72                               N     1.0        0.0
# ..                             ...     ...        ...
# 870                              N       N          N
# 254                              N     1.0        0.0
# 935                              N       N          N
# 415                              N       N          N
# 779                              N       N          N
#
# [100 rows x 22 columns]

# %%
test_df.to_csv("fine-tune/test.csv",index=None)

# %% [markdown]
# ## 3.1 Create the fine-tuning datasets for Q&A and discriminator models
# The fine-tuning dataset is created in the following way. For every corresponding question, answer and context pair we create:
# - Positive example: correct question, answer, context pair
# - Negative examples:
#   - random negative example, where the random context is paired with the question
#   - two hard negative examples
#     - one originating from the same wikipedia article
#     - another, which is most similar to the correct context
#
# This process is noisy, as sometimes the question might be answerable given a different context, but on average we hope this won't affect the peformance too much.
#
# We apply the same process of dataset creation for both the discriminator, and the Q&A answering model. We apply the process separately for the training and testing set, to ensure that the examples from the training set don't feature within the test set.

# %%
def create_prompt(df, col):
    rows = []
    if col == "ETD":
        col_name = "y_ETD"
    else:
        col_name = "y_PS"
    for i, row in df.iterrows():
        rows.append({"prompt": f"{row.issue_clean.strip()}\n\n###\n\n", "completion": f"{row[col_name]}"})
    
    return pd.DataFrame(rows)

# %%
def create_prompt2(df, discriminator=False):
    rows = []
    for i, row in df.iterrows():
        rationale = row.PS_sent.strip()
        rationale_prompt = ""
        answer = row.PS.strip().upper()
        if not discriminator:
            if answer == "Y":
                rationale_prompt = 'The sentence \"'+rationale+'\" describes PS.'
            else:
                rationale_prompt = "Not found PS."
        if discriminator:
            rows.append({"prompt":f"Question: {row.Issues.strip()}\n Related:", "completion":f" {answer}"})
        else:
            rows.append({"prompt":f"Question: {row.Issues.strip()}\nAnswer:", "completion":f"{rationale_prompt}"})

    
    return pd.DataFrame(rows)

# %%
ft = create_prompt(train_df, "ETD")
ft.to_json('fine-tune/train_ETD.jsonl', orient='records', lines=True)

# %%
ft = create_prompt(val_df, "ETD")
ft.to_json('fine-tune/val_ETD.jsonl', orient='records', lines=True)

# %%
ft = create_prompt(train_df, "PS")
ft.to_json('fine-tune/train_PS.jsonl', orient='records', lines=True)

# %%
ft = create_prompt(val_df, "PS")
ft.to_json('fine-tune/val_PS.jsonl', orient='records', lines=True)

# %%
for name, is_disc in [('discriminator', True)]:
    for train_test, dt in [('train', train_df), ('test', test_df)]:
        ft = create_prompt(dt, discriminator=is_disc)
        ft.to_json(f'{name}_{train_test}.jsonl', orient='records', lines=True)

# %% [markdown]
# We apply the same process of dataset creation for both the discriminator, and the Q&A answering model. We apply the process separately for the training and testing set, to ensure that the examples from the training set don't feature within the test set.

# %%
for name, is_disc in [('qa', False)]:
    for train_test, dt in [('train', train_df), ('test', test_df)]:
        ft = create_prompt(dt, discriminator=is_disc)
        ft.to_json(f'{name}_{train_test}.jsonl', orient='records', lines=True)

# %% [markdown]
# We formatted the data according to the recommendations from the fine-tuning tool, which is available using
# > openai tools fine_tunes.prepare_data -f qa_train.jsonl
#
# We highly recommend that you use this tool, which suggests improvements in your data formatting for fine-tuning.

# %% [markdown]
# ## 3.2 Submit the datasets for fine-tuning

# %%
import os

# Set your OpenAI API key here
openai.api_key = "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"

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.create -t "fine-tune/train_ETD.jsonl" -v "fine-tune/val_ETD.jsonl" --batch_size 16  --compute_classification_metrics --classification_positive_class " 1" --model babbage
# Out:
# ^C

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.follow -i ft-RCKBxT3rh7juE2SJgjVwBadx
# Out:
# [2023-12-12 02:52:50] Created fine-tune: ft-RCKBxT3rh7juE2SJgjVwBadx
# [2023-12-12 02:52:56] Fine-tune costs $0.12
# [2023-12-12 02:52:56] Fine-tune enqueued. Queue number: 0
# [2023-12-12 02:52:58] Fine-tune started
# [2023-12-12 02:53:43] Completed epoch 1/4
# [2023-12-12 02:54:09] Completed epoch 2/4
# [2023-12-12 02:54:34] Completed epoch 3/4
# [2023-12-12 02:54:59] Completed epoch 4/4
# [2023-12-12 02:55:21] Uploaded model: babbage:ft-simin-2023-12-12-08-55-21
# [2023-12-12 02:55:23] Uploaded result file: file-FdzILLTWslDHAxUGGKWaqoV1
# [2023-12-12 02:55:23] Fine-tune succeeded
# Traceback (most recent call last):
#   File "C:\Users\wangs\anaconda3\envs\openai\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\wangs\anaconda3\envs\openai\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\wangs\anaconda3\envs\openai\Scripts\openai.exe\__main__.py", line 7, in <module>
#   File "C:\Users\wangs\anaconda3\envs\openai\lib\site-packages\openai\_openai_scripts.py", line 78, in main
#     args.func(args)
#   File "C:\Users\wangs\anaconda3\envs\openai\lib\site-packages\openai\cli.py", line 516, in follow
#     cls._stream_events(args.id)
#   File "C:\Users\wangs\anaconda3\envs\openai\lib\site-packages\openai\cli.py", line 559, in _stream_events
#     sys.stdout.write("\nJob complete! Status: succeeded \U0001f389")
#   File "C:\Users\wangs\anaconda3\envs\openai\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f389' in position 34: character maps to <undefined>

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.create -t "discriminator_train.jsonl" -v "discriminator_test.jsonl" --batch_size 16  --compute_classification_metrics --classification_positive_class " Y" --model ada
# Out:
# Uploaded file from discriminator_train.jsonl: file-POcryJ6XekFjaBamYOdrbgCe
# Uploaded file from discriminator_test.jsonl: file-kvfWd2nsI921xV7SQ7ArWfPL
# Created fine-tune: ft-UNVL8XhOxKiniBK61el3plQy
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2023-06-06 10:05:58] Created fine-tune: ft-UNVL8XhOxKiniBK61el3plQy
# Upload progress:   0%|          | 0.00/197k [00:00<?, ?it/s]
# Upload progress: 100%|##########| 197k/197k [00:00<?, ?it/s]
#
# Upload progress:   0%|          | 0.00/45.4k [00:00<?, ?it/s]
# Upload progress: 100%|##########| 45.4k/45.4k [00:00<?, ?it/s]

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.follow -i ft-UNVL8XhOxKiniBK61el3plQy
# Out:
# [2023-06-06 10:05:58] Created fine-tune: ft-UNVL8XhOxKiniBK61el3plQy
# [2023-06-06 10:11:13] Fine-tune costs $0.08
# [2023-06-06 10:11:13] Fine-tune enqueued. Queue number: 4
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-UNVL8XhOxKiniBK61el3plQy

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.list
# Out:
# {
#   "data": [
#     {
#       "created_at": 1684374005,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 16,
#         "classification_positive_class": "Y",
#         "compute_classification_metrics": true,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-pssWbqtm0TWZuPg71rGXdNni",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [],
#       "status": "failed",
#       "training_files": [
#         {
#           "bytes": 247230,
#           "created_at": 1684374003,
#           "filename": "discriminator_train.jsonl",
#           "id": "file-y0VsOpeStMECbgtqm3OeFTt3",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684374126,
#       "validation_files": [
#         {
#           "bytes": 58018,
#           "created_at": 1684374005,
#           "filename": "discriminator_test.jsonl",
#           "id": "file-ksTsl9lbw3QF7ZQftqz3QWom",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1684374540,
#       "fine_tuned_model": "ada:ft-personal-2023-05-18-02-02-38",
#       "hyperparams": {
#         "batch_size": 16,
#         "classification_positive_class": "Y",
#         "compute_classification_metrics": true,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-YO72JVF3G4ISysv0e18W9ouV",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [
#         {
#           "bytes": 7108,
#           "created_at": 1684375359,
#           "filename": "compiled_results.csv",
#           "id": "file-fnw0LXhKYep23VEuW2jCU3Ti",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 246775,
#           "created_at": 1684374538,
#           "filename": "discriminator_train.jsonl",
#           "id": "file-ZJosxsteI87lT6dNkltcUmcs",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684375359,
#       "validation_files": [
#         {
#           "bytes": 57904,
#           "created_at": 1684374539,
#           "filename": "discriminator_test.jsonl",
#           "id": "file-ipUITAqQLNGfm2O4bid1JhKc",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1684374853,
#       "fine_tuned_model": "curie:ft-personal-2023-05-18-02-09-01",
#       "hyperparams": {
#         "batch_size": 16,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-3sgqLtyDmd73F7qEIOhwUetp",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [
#         {
#           "bytes": 7223,
#           "created_at": 1684375741,
#           "filename": "compiled_results.csv",
#           "id": "file-kZPYFQDdk5VjfOVeTgS7HqHM",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 257116,
#           "created_at": 1684374851,
#           "filename": "qa_train.jsonl",
#           "id": "file-vVDP6LGEhgNQxPzFuV0HzGOp",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684375742,
#       "validation_files": [
#         {
#           "bytes": 60496,
#           "created_at": 1684374852,
#           "filename": "qa_test.jsonl",
#           "id": "file-JEmaJz3VhpKD0e9K19TKmA0p",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1684378484,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 16,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-CIxlKEkKfa0v9FmPiuNQZSGc",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [],
#       "status": "failed",
#       "training_files": [
#         {
#           "bytes": 262121,
#           "created_at": 1684378482,
#           "filename": "qa_train.jsonl",
#           "id": "file-pYTgqb2QJM0uwp99xvLqvNKI",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684380424,
#       "validation_files": [
#         {
#           "bytes": 61750,
#           "created_at": 1684378484,
#           "filename": "qa_test.jsonl",
#           "id": "file-pDwDhZrXEFXC9hc6dH1EuWYM",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1684380692,
#       "fine_tuned_model": "curie:ft-personal-2023-05-18-03-46-16",
#       "hyperparams": {
#         "batch_size": 16,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-SgmTPgmDJP5sM0MCE0NMIuGO",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [
#         {
#           "bytes": 7942,
#           "created_at": 1684381577,
#           "filename": "compiled_results.csv",
#           "id": "file-4k4P6n60Y3ani4OM0mBo7jex",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 228734,
#           "created_at": 1684380691,
#           "filename": "qa_train.jsonl",
#           "id": "file-TEwzl2nJ51sR5IQZqnQ4OYcX",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684381578,
#       "validation_files": [
#         {
#           "bytes": 53389,
#           "created_at": 1684380692,
#           "filename": "qa_test.jsonl",
#           "id": "file-CwzG27aqhMF1UsnnvJ0y68GX",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1686063958,
#       "fine_tuned_model": "ada:ft-personal-2023-06-06-15-27-10",
#       "hyperparams": {
#         "batch_size": 16,
#         "classification_positive_class": " Y",
#         "compute_classification_metrics": true,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-UNVL8XhOxKiniBK61el3plQy",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [
#         {
#           "bytes": 7569,
#           "created_at": 1686065231,
#           "filename": "compiled_results.csv",
#           "id": "file-fM3vsDwJ9GfxDqQp9aDidV9L",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 196737,
#           "created_at": 1686063956,
#           "filename": "discriminator_train.jsonl",
#           "id": "file-POcryJ6XekFjaBamYOdrbgCe",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1686065231,
#       "validation_files": [
#         {
#           "bytes": 45405,
#           "created_at": 1686063958,
#           "filename": "discriminator_test.jsonl",
#           "id": "file-kvfWd2nsI921xV7SQ7ArWfPL",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1702371170,
#       "fine_tuned_model": "babbage:ft-simin-2023-12-12-08-55-21",
#       "hyperparams": {
#         "batch_size": 16,
#         "classification_positive_class": "1",
#         "compute_classification_metrics": true,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-RCKBxT3rh7juE2SJgjVwBadx",
#       "model": "babbage",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [
#         {
#           "bytes": 12865,
#           "created_at": 1702371322,
#           "filename": "compiled_results.csv",
#           "id": "file-FdzILLTWslDHAxUGGKWaqoV1",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 233895,
#           "created_at": 1702371169,
#           "filename": "fine-tune/train_ETD.jsonl",
#           "id": "file-VbIRIMlSkv7Sqq7W0iOHUPwA",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1702371323,
#       "validation_files": [
#         {
#           "bytes": 29476,
#           "created_at": 1702371170,
#           "filename": "fine-tune/val_ETD.jsonl",
#           "id": "file-dydGf7aERqFNOQSYGVhbQ68W",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     }
#   ],
#   "next_starting_after": null,
#   "object": "list"
# }

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.results -i ft-UNVL8XhOxKiniBK61el3plQy
# Out:
# step,elapsed_tokens,elapsed_examples,training_loss,training_sequence_accuracy,training_token_accuracy,validation_loss,validation_sequence_accuracy,validation_token_accuracy,classification/accuracy,classification/precision,classification/recall,classification/auroc,classification/auprc,classification/f1.0
# 1,2576,16,0.07475356098253211,0.0,0.0,0.056984589227910616,0.0,0.0,,,,,,
# 2,4896,32,0.07295184697370169,0.0,0.0,,,,,,,,,
# 3,9520,48,0.03314938379399553,0.0,0.0,,,,,,,,,
# 4,13760,64,0.03030696158179472,0.125,0.125,,,,,,,,,
# 5,16848,80,0.033391947288160535,0.625,0.625,,,,,,,,,
# 6,19552,96,0.028766080635341935,0.4375,0.4375,,,,,,,,,
# 7,23152,112,0.028488615856709983,0.3125,0.3125,,,,,,,,,
# 8,25600,128,0.029105414819410296,0.75,0.75,,,,,,,,,
# 9,29072,144,0.022060113265728334,0.75,0.75,0.02002050457952892,0.5625,0.5625,,,,,,
# 10,32416,160,0.023664789164665613,0.625,0.625,,,,,,,,,
# 11,34992,176,0.027904583653565167,0.9375,0.9375,,,,,,,,,
# 12,46016,192,0.007985922258405465,0.8125,0.8125,,,,,,,,,
# 13,49744,208,0.019032073212738004,0.75,0.75,,,,,,,,,
# 14,53600,224,0.01857425783338937,0.8125,0.8125,,,,,,,,,
# 15,58096,240,0.015354838290301293,0.6875,0.6875,,,,,,,,,
# 16,61312,256,0.024080465346750315,0.625,0.625,,,,,,,,,
# 17,63504,272,0.02970763985124704,0.75,0.75,0.01838266122361052,0.75,0.75,,,,,,
# 18,66464,288,0.021670533034451617,0.5625,0.5625,,,,,,,,,
# 19,69552,304,0.022363368833793706,0.625,0.625,,,,,,,,,
# 20,72384,320,0.022494408079299897,0.875,0.875,,,,,,,,,
# 21,74832,336,0.027205421026718506,0.875,0.875,,,,,,,,,
# 22,77920,352,0.019995915538014896,0.875,0.875,,,,,,,,,
# 23,79856,368,0.027608281605919428,0.8125,0.8125,,,,,,,,,
# 24,82816,384,0.022060614377546896,0.8125,0.8125,,,,,,,,,
# 25,85392,400,0.02147638801035487,1.0,1.0,0.026088710520583556,0.6875,0.6875,,,,,,
# 26,88352,416,0.024993340791431326,0.625,0.625,,,,,,,,,
# 27,92336,432,0.01817838611562233,0.8125,0.8125,,,,,,,,,
# 28,94912,448,0.024456482886225327,0.875,0.875,,,,,,,,,
# 29,97232,464,0.02165104086187341,0.75,0.75,,,,,,,,,
# 30,99808,480,0.0227615969421845,0.9375,0.9375,,,,0.8070175647735596,0.9154929577464789,0.8024691358024691,0.8900112233445566,0.9507358354021253,0.8552631578947367
# 31,102384,496,0.021835222046572882,0.875,0.875,,,,,,,,,
# 32,104960,512,0.020128772022645024,0.875,0.875,,,,,,,,,
# 33,107408,528,0.02242434019820431,0.75,0.75,0.0223217722164908,0.875,0.875,,,,,,
# 34,109984,544,0.023659832918038033,0.6875,0.6875,,,,,,,,,
# 35,114480,560,0.013826202837230834,0.9375,0.9375,,,,,,,,,
# 36,117056,576,0.020759625465481362,0.9375,0.9375,,,,,,,,,
# 37,121680,592,0.013008647875409183,0.9375,0.9375,,,,,,,,,
# 38,124512,608,0.026214366256631164,0.625,0.625,,,,,,,,,
# 39,127472,624,0.017806403918885303,0.8125,0.8125,,,,,,,,,
# 40,130048,640,0.02332267694592114,0.875,0.875,,,,,,,,,
# 41,133264,656,0.019943490654316127,0.6875,0.6875,0.02032917463708676,0.8125,0.8125,,,,,,
# 42,137120,672,0.014929197008497201,0.6875,0.6875,,,,,,,,,
# 43,140720,688,0.018998444624898272,0.8125,0.8125,,,,,,,,,
# 44,144960,704,0.01603428556810366,0.75,0.75,,,,,,,,,
# 45,147920,720,0.02208179219338499,0.75,0.75,,,,,,,,,
# 46,151904,736,0.014630391803395858,1.0,1.0,,,,,,,,,
# 47,154480,752,0.023865773374663463,0.875,0.875,,,,,,,,,
# 48,156928,768,0.024105155803274724,0.875,0.875,,,,,,,,,
# 49,160912,784,0.016431876673694817,0.9375,0.9375,0.023706315888012603,0.875,0.875,,,,,,
# 50,164640,800,0.01629412383281523,0.8125,0.8125,,,,,,,,,
# 51,167472,816,0.01999970173892551,1.0,1.0,,,,,,,,,
# 52,170304,832,0.02030468285211821,0.9375,0.9375,,,,,,,,,
# 53,173776,848,0.019377405163487352,0.875,0.875,,,,,,,,,
# 54,176992,864,0.0175946509271653,1.0,1.0,,,,,,,,,
# 55,179952,880,0.02153803054793101,0.9375,0.9375,,,,,,,,,
# 56,182912,896,0.02191952016508305,0.875,0.875,,,,,,,,,
# 57,193936,912,0.006341407826545436,0.75,0.75,0.020766627509492708,0.9375,0.9375,,,,,,
# 58,197536,928,0.015203191830504063,0.9375,0.9375,,,,,,,,,
# 59,200624,944,0.02032958191092021,0.9375,0.9375,,,,0.8157894611358643,0.8846153846153846,0.8518518518518519,0.9188178077066966,0.9642149839476155,0.8679245283018868
# 60,205120,960,0.015738713617192604,0.875,0.875,,,,,,,,,
# 61,208208,976,0.018587674655753377,0.875,0.875,,,,,,,,,
# 62,211296,992,0.019436133404872276,0.875,0.875,,,,,,,,,
# 63,214256,1008,0.019172518240310955,0.875,0.875,,,,,,,,,
# 64,217472,1024,0.019803337097227723,0.875,0.875,,,,,,,,,
# 65,220560,1040,0.02211697980831905,0.9375,0.9375,0.02032676184310742,0.75,0.75,,,,,,
# 66,223904,1056,0.016741846170346415,1.0,1.0,,,,,,,,,
# 67,228528,1072,0.009627945800794326,1.0,1.0,,,,,,,,,
# 68,230848,1088,0.025336412354375,0.875,0.875,,,,,,,,,
# 69,235472,1104,0.01153310315635894,0.9375,0.9375,,,,,,,,,
# 70,237920,1120,0.021816444629681988,0.875,0.875,,,,,,,,,
# 71,240368,1136,0.02202007988005179,0.8125,0.8125,,,,,,,,,
# 72,243328,1152,0.019744596260991426,1.0,1.0,,,,,,,,,
# 73,247056,1168,0.015912407871722014,0.875,0.875,0.024080524278038227,0.875,0.875,,,,,,
# 74,258080,1184,0.005070649300852686,0.9375,0.9375,,,,,,,,,
# 75,262064,1200,0.013139688622673057,1.0,1.0,,,,,,,,,
# 76,265024,1216,0.017623914368001925,0.9375,0.9375,,,,,,,,,
# 77,267344,1232,0.021122917643956532,0.9375,0.9375,,,,,,,,,
# 78,269280,1248,0.0282795184498425,0.875,0.875,,,,,,,,,
# 79,272496,1264,0.01849294300714064,1.0,1.0,,,,,,,,,
# 80,274944,1280,0.020439302684610704,0.9375,0.9375,,,,,,,,,
# 81,277776,1296,0.019304067520338957,0.875,0.875,0.024042902558158122,0.8125,0.8125,,,,,,
# 82,280352,1312,0.02059597474254352,0.9375,0.9375,,,,,,,,,
# 83,282928,1328,0.0220174434173245,0.9375,0.9375,,,,,,,,,
# 84,286784,1344,0.017058530086085058,0.8125,0.8125,,,,,,,,,
# 85,289616,1360,0.01988183069678036,0.9375,0.9375,,,,,,,,,
# 86,291936,1376,0.023807575750066184,0.9375,0.9375,,,,,,,,,
# 87,294256,1392,0.024532620453167814,0.875,0.875,,,,,,,,,
# 88,296832,1408,0.023337021310573143,0.9375,0.9375,,,,0.859649121761322,0.8651685393258427,0.9506172839506173,0.9319117096894874,0.969624972776077,0.9058823529411766
# 89,300176,1424,0.017375969911908817,0.9375,0.9375,0.02025608854323863,1.0,1.0,,,,,,
# 90,304160,1440,0.015182830904596106,0.8125,0.8125,,,,,,,,,
# 91,308784,1456,0.012623888051344784,0.875,0.875,,,,,,,,,
# 92,312000,1472,0.015125199190721242,0.9375,0.9375,,,,,,,,,
# 93,315728,1488,0.016031353585625862,0.9375,0.9375,,,,,,,,,
# 94,326752,1504,0.005441259303795862,0.75,0.75,,,,,,,,,
# 95,330736,1520,0.013056253023454952,0.9375,0.9375,,,,,,,,,
# 96,334976,1536,0.012326688653988265,0.875,0.875,,,,,,,,,
# 97,336912,1552,0.02549870777503848,1.0,1.0,0.01478101867477984,0.875,0.875,,,,,,
# 98,339488,1568,0.01820904031100024,1.0,1.0,,,,,,,,,
# 99,342576,1584,0.017392103268571074,1.0,1.0,,,,,,,,,
# 100,345408,1600,0.019260762265500893,0.9375,0.9375,,,,,,,,,
# 101,348624,1616,0.0176736989726106,1.0,1.0,,,,,,,,,
# 102,351584,1632,0.0194100157588053,0.875,0.875,,,,,,,,,
# 103,353392,1648,0.02313275020088911,0.9375,0.9375,,,,,,,,,
# 104,356352,1664,0.016715662975129993,0.875,0.875,,,,,,,,,
# 105,359824,1680,0.017420990036926688,0.9375,0.9375,0.01789050919397025,0.875,0.875,,,,,,
# 106,363040,1696,0.017002344297184894,1.0,1.0,,,,,,,,,
# 107,366000,1712,0.019989571695709564,1.0,1.0,,,,,,,,,
# 108,369088,1728,0.017917211080375497,1.0,1.0,,,,,,,,,
# 109,371536,1744,0.019138571654708992,1.0,1.0,,,,,,,,,
# 110,376160,1760,0.011563252350603058,0.875,0.875,,,,,,,,,
# 111,378736,1776,0.02405365870594153,0.875,0.875,,,,,,,,,
# 112,382592,1792,0.015771309731384405,1.0,1.0,,,,,,,,,
# 113,385168,1808,0.02182401239268384,0.9375,0.9375,0.022638263879295052,0.8125,0.8125,,,,,,
# 114,388256,1824,0.020902838990568096,0.875,0.875,,,,,,,,,
# 115,391472,1840,0.01869830745162169,0.875,0.875,,,,0.8684210777282715,0.9125,0.9012345679012346,0.934156378600823,0.9702735435279137,0.9068322981366459

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.create -t "qa_train.jsonl" -v "qa_test.jsonl" --batch_size 16
# Out:
# Uploaded file from qa_train.jsonl: file-TEwzl2nJ51sR5IQZqnQ4OYcX
# Uploaded file from qa_test.jsonl: file-CwzG27aqhMF1UsnnvJ0y68GX
# Created fine-tune: ft-SgmTPgmDJP5sM0MCE0NMIuGO
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2023-05-17 22:31:32] Created fine-tune: ft-SgmTPgmDJP5sM0MCE0NMIuGO
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-SgmTPgmDJP5sM0MCE0NMIuGO
# Upload progress:   0%|          | 0.00/229k [00:00<?, ?it/s]
# Upload progress: 100%|##########| 229k/229k [00:00<?, ?it/s]
#
# Upload progress:   0%|          | 0.00/53.4k [00:00<?, ?it/s]
# Upload progress: 100%|##########| 53.4k/53.4k [00:00<00:00, 53.5Mit/s]

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.follow -i ft-SgmTPgmDJP5sM0MCE0NMIuGO
# Out:
# [2023-05-17 22:31:32] Created fine-tune: ft-SgmTPgmDJP5sM0MCE0NMIuGO
# [2023-05-17 22:33:49] Fine-tune costs $0.66
# [2023-05-17 22:33:50] Fine-tune enqueued. Queue number: 0

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.list
# Out:
# {
#   "data": [
#     {
#       "created_at": 1684374005,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 16,
#         "classification_positive_class": "Y",
#         "compute_classification_metrics": true,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-pssWbqtm0TWZuPg71rGXdNni",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [],
#       "status": "failed",
#       "training_files": [
#         {
#           "bytes": 247230,
#           "created_at": 1684374003,
#           "filename": "discriminator_train.jsonl",
#           "id": "file-y0VsOpeStMECbgtqm3OeFTt3",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684374126,
#       "validation_files": [
#         {
#           "bytes": 58018,
#           "created_at": 1684374005,
#           "filename": "discriminator_test.jsonl",
#           "id": "file-ksTsl9lbw3QF7ZQftqz3QWom",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1684374540,
#       "fine_tuned_model": "ada:ft-personal-2023-05-18-02-02-38",
#       "hyperparams": {
#         "batch_size": 16,
#         "classification_positive_class": "Y",
#         "compute_classification_metrics": true,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-YO72JVF3G4ISysv0e18W9ouV",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [
#         {
#           "bytes": 7108,
#           "created_at": 1684375359,
#           "filename": "compiled_results.csv",
#           "id": "file-fnw0LXhKYep23VEuW2jCU3Ti",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 246775,
#           "created_at": 1684374538,
#           "filename": "discriminator_train.jsonl",
#           "id": "file-ZJosxsteI87lT6dNkltcUmcs",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684375359,
#       "validation_files": [
#         {
#           "bytes": 57904,
#           "created_at": 1684374539,
#           "filename": "discriminator_test.jsonl",
#           "id": "file-ipUITAqQLNGfm2O4bid1JhKc",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1684374853,
#       "fine_tuned_model": "curie:ft-personal-2023-05-18-02-09-01",
#       "hyperparams": {
#         "batch_size": 16,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-3sgqLtyDmd73F7qEIOhwUetp",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [
#         {
#           "bytes": 7223,
#           "created_at": 1684375741,
#           "filename": "compiled_results.csv",
#           "id": "file-kZPYFQDdk5VjfOVeTgS7HqHM",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 257116,
#           "created_at": 1684374851,
#           "filename": "qa_train.jsonl",
#           "id": "file-vVDP6LGEhgNQxPzFuV0HzGOp",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684375742,
#       "validation_files": [
#         {
#           "bytes": 60496,
#           "created_at": 1684374852,
#           "filename": "qa_test.jsonl",
#           "id": "file-JEmaJz3VhpKD0e9K19TKmA0p",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1684378484,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 16,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-CIxlKEkKfa0v9FmPiuNQZSGc",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [],
#       "status": "failed",
#       "training_files": [
#         {
#           "bytes": 262121,
#           "created_at": 1684378482,
#           "filename": "qa_train.jsonl",
#           "id": "file-pYTgqb2QJM0uwp99xvLqvNKI",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684380424,
#       "validation_files": [
#         {
#           "bytes": 61750,
#           "created_at": 1684378484,
#           "filename": "qa_test.jsonl",
#           "id": "file-pDwDhZrXEFXC9hc6dH1EuWYM",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     },
#     {
#       "created_at": 1684380692,
#       "fine_tuned_model": "curie:ft-personal-2023-05-18-03-46-16",
#       "hyperparams": {
#         "batch_size": 16,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-SgmTPgmDJP5sM0MCE0NMIuGO",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-cJuYelQwjRBm9vJYIPTIyGCp",
#       "result_files": [
#         {
#           "bytes": 7942,
#           "created_at": 1684381577,
#           "filename": "compiled_results.csv",
#           "id": "file-4k4P6n60Y3ani4OM0mBo7jex",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 228734,
#           "created_at": 1684380691,
#           "filename": "qa_train.jsonl",
#           "id": "file-TEwzl2nJ51sR5IQZqnQ4OYcX",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1684381578,
#       "validation_files": [
#         {
#           "bytes": 53389,
#           "created_at": 1684380692,
#           "filename": "qa_test.jsonl",
#           "id": "file-CwzG27aqhMF1UsnnvJ0y68GX",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ]
#     }
#   ],
#   "object": "list"
# }

# %%
# !C:\Users\wangs\anaconda3\envs\openai\Scripts\openai api fine_tunes.results -i ft-SgmTPgmDJP5sM0MCE0NMIuGO
# Out:
# step,elapsed_tokens,elapsed_examples,training_loss,training_sequence_accuracy,training_token_accuracy,validation_loss,validation_sequence_accuracy,validation_token_accuracy
# 1,3600,16,0.2176661549346172,0.0,0.5967078189300411,0.28236025374051127,0.0,0.5215311004784688
# 2,7712,32,0.21680914663504308,0.0,0.6723646723646723,,,
# 3,11312,48,0.23068295322122226,0.0,0.6325878594249201,,,
# 4,16192,64,0.15076864943360166,0.0,0.6875,,,
# 5,19664,80,0.1890967075932473,0.0,0.6118143459915611,,,
# 6,30944,96,0.047796214772790196,0.0,0.6419213973799127,,,
# 7,34160,112,0.16214998225114413,0.0,0.6996197718631179,,,
# 8,37632,128,0.12382641752946867,0.0,0.6979591836734694,,,
# 9,40592,144,0.11680326698984142,0.0,0.7058823529411765,0.08725531779303117,0.0,0.7857142857142857
# 10,44448,160,0.0746257752198511,0.0,0.834733893557423,,,
# 11,47792,176,0.06417853658018235,0.0,0.8717948717948718,,,
# 12,51136,192,0.051729317171417696,0.0625,0.89568345323741,,,
# 13,53840,208,0.05564869891130288,0.0,0.8939393939393939,,,
# 14,57056,224,0.05248212818011317,0.125,0.891156462585034,,,
# 15,60144,240,0.049954748825152016,0.125,0.9269005847953217,,,
# 16,62976,256,0.038578568393249364,0.1875,0.9035532994923858,,,
# 17,67856,272,0.039724848173916166,0.1875,0.8375,0.05883894639312211,0.1875,0.8871473354231975
# 18,71968,288,0.04804156629036839,0.125,0.8901734104046243,,,
# 19,75312,304,0.05145154606823089,0.0625,0.8964401294498382,,,
# 20,80064,320,0.02684921942602672,0.0625,0.8888888888888888,,,
# 21,83280,336,0.043859348733495736,0.125,0.8969957081545065,,,
# 22,86368,352,0.047033909784299645,0.0625,0.9039145907473309,,,
# 23,89712,368,0.04702303558195084,0.125,0.9127906976744186,,,
# 24,92672,384,0.034388946878092214,0.5,0.9137931034482759,,,
# 25,96016,400,0.03950372557399662,0.3125,0.9037037037037037,0.06424717771271196,0.1875,0.9038461538461539
# 26,99232,416,0.03728732662617995,0.25,0.9204152249134948,,,
# 27,103728,432,0.03336223962574401,0.0625,0.9187279151943463,,,
# 28,107072,448,0.03783244868774716,0.125,0.9310344827586207,,,
# 29,109904,464,0.03436617711524163,0.1875,0.9285714285714286,,,
# 30,113120,480,0.03198511546735499,0.125,0.9182879377431906,,,
# 31,116336,496,0.044893908066379176,0.0,0.9123376623376623,,,
# 32,120448,512,0.027911114488384597,0.4375,0.954954954954955,,,
# 33,125328,528,0.028019650587186834,0.3125,0.9149797570850202,0.030750025559280542,0.1875,0.9178571428571428
# 34,128032,544,0.05299823758910169,0.1875,0.9128919860627178,,,
# 35,130864,560,0.03604983634829327,0.3125,0.9227799227799228,,,
# 36,134336,576,0.027394484884600147,0.375,0.9444444444444444,,,
# 37,145616,592,0.01088890951632252,0.0625,0.9254658385093167,,,
# 38,150112,608,0.025252174629515334,0.3125,0.9365671641791045,,,
# 39,153328,624,0.033865617129902784,0.3125,0.9368421052631579,,,
# 40,158080,640,0.02685965127320571,0.25,0.919732441471572,,,
# 41,161552,656,0.029645426852605967,0.3125,0.9356223175965666,0.028314023195689795,0.4375,0.929368029739777
# 42,164896,672,0.029391680436924708,0.375,0.9372549019607843,,,
# 43,167600,688,0.03260326404610046,0.4375,0.9493670886075949,,,
# 44,170432,704,0.03125304968409774,0.5,0.9487179487179487,,,
# 45,174544,720,0.026276412297503972,0.3125,0.90625,,,
# 46,178144,736,0.026181177557504636,0.4375,0.9318181818181818,,,
# 47,181104,752,0.04038504882073546,0.125,0.9298245614035088,,,
# 48,185216,768,0.019093169465780324,0.375,0.9436619718309859,,,
# 49,188304,784,0.03017669910684817,0.3125,0.9487179487179487,0.03579155930240238,0.25,0.9437086092715232
# 50,192800,800,0.019101950984099676,0.1875,0.9269406392694064,,,
# 51,196400,816,0.031955005133989724,0.3125,0.9517045454545454,,,
# 52,199872,832,0.03320417542193982,0.3125,0.9523809523809523,,,
# 53,202576,848,0.04532815282685592,0.25,0.9376854599406528,,,
# 54,206432,864,0.036584232555125364,0.3125,0.9246031746031746,,,
# 55,208752,880,0.0378006009201166,0.4375,0.9326923076923077,,,
# 56,213632,896,0.0261518024574567,0.3125,0.9339622641509434,,,
# 57,217104,912,0.030837266140715285,0.3125,0.9446064139941691,0.035927609214223166,0.375,0.9270833333333334
# 58,219936,928,0.029137761696592657,0.5625,0.9626168224299065,,,
# 59,223408,944,0.025868691306216083,0.5,0.9528619528619529,,,
# 60,226880,960,0.02331944142687352,0.4375,0.9377777777777778,,,
# 61,229968,976,0.034773331407344114,0.3125,0.9348659003831418,,,
# 62,232160,992,0.03659038068469531,0.5625,0.9484978540772532,,,
# 63,234992,1008,0.031627887814493785,0.5625,0.962457337883959,,,
# 64,239744,1024,0.025255214099034393,0.375,0.9485714285714286,,,
# 65,242960,1040,0.0324758919234305,0.4375,0.9411764705882353,0.038500021593156526,0.3125,0.926829268292683
# 66,247456,1056,0.021709102505674514,0.4375,0.9525423728813559,,,
# 67,250288,1072,0.032478717134637354,0.375,0.9615384615384616,,,
# 68,253504,1088,0.02516972350668771,0.25,0.916256157635468,,,
# 69,256976,1104,0.027028093306890415,0.4375,0.9315789473684211,,,
# 70,260320,1120,0.029174897424346573,0.375,0.9352226720647774,,,
# 71,263920,1136,0.02406097732265574,0.3125,0.9432314410480349,,,
# 72,268032,1152,0.033070661826222154,0.5,0.9312714776632303,,,
# 73,270608,1168,0.03549169960213258,0.25,0.9384057971014492,0.03226866894379403,0.4375,0.926829268292683
# 74,281888,1184,0.00789906948826549,0.375,0.9509803921568627,,,
# 75,285360,1200,0.029220582504015682,0.25,0.9404388714733543,,,
# 76,289216,1216,0.020841053653917346,0.5625,0.9709677419354839,,,
# 77,292048,1232,0.03190326323840804,0.5,0.9628482972136223,,,
# 78,295648,1248,0.027225627459197554,0.375,0.9421221864951769,,,
# 79,298992,1264,0.028833875111488407,0.3125,0.947565543071161,,,
# 80,303488,1280,0.021389306448961382,0.3125,0.9479553903345725,,,
# 81,306832,1296,0.026883670634440526,0.3125,0.9457013574660633,0.03869372519796898,0.125,0.9027237354085603
# 82,311712,1312,0.01936974622833315,0.4375,0.9573770491803278,,,
# 83,315056,1328,0.028335819925895962,0.375,0.9488054607508533,,,
# 84,319936,1344,0.01994153703469692,0.3125,0.9430604982206405,,,
# 85,322256,1360,0.035543333363126935,0.25,0.9547038327526133,,,
# 86,325216,1376,0.038670719528277,0.4375,0.9501557632398754,,,
# 87,329712,1392,0.018835227762829577,0.3125,0.9467213114754098,,,
# 88,334464,1408,0.020101601595873188,0.375,0.9554794520547946,,,
# 89,337552,1424,0.028154263520886343,0.4375,0.9628252788104089,0.03107485583927394,0.25,0.9354005167958657
# 90,342432,1440,0.02094990097306971,0.1875,0.9523809523809523,,,
# 91,345264,1456,0.02798224950928253,0.6875,0.9781021897810219,,,
# 92,348608,1472,0.024805317081187186,0.4375,0.97,,,
# 93,351952,1488,0.026010165369374765,0.25,0.9221789883268483,,,
# 94,355168,1504,0.034887278293695444,0.5,0.9545454545454546,,,
# 95,360048,1520,0.018745820134258545,0.4375,0.9523809523809523,,,
# 96,371328,1536,0.00829331089177425,0.3125,0.926984126984127,,,
# 97,375184,1552,0.02236327161787029,0.375,0.9429657794676806,0.03245722162283897,0.1875,0.9151515151515152
# 98,378656,1568,0.021528003170740082,0.625,0.9595959595959596,,,
# 99,382128,1584,0.022712643846265167,0.6875,0.9497206703910615,,,
# 100,385600,1600,0.030575279506969963,0.4375,0.9523809523809523,,,
# 101,388688,1616,0.02888615658347074,0.375,0.9477611940298507,,,
# 102,392032,1632,0.022961941105444212,0.5625,0.9713261648745519,,,
# 103,394224,1648,0.024253898570815443,0.75,0.978494623655914,,,
# 104,398336,1664,0.02166765987977209,0.4375,0.9654088050314465,,,
# 105,401680,1680,0.03108944406318068,0.25,0.9478827361563518,0.03808211301016078,0.1875,0.9378531073446328
# 106,404896,1696,0.02276995178308292,0.375,0.946969696969697,,,
# 107,407728,1712,0.027366973640236648,0.375,0.9539007092198581,,,
# 108,411840,1728,0.018171120633640195,0.5625,0.943127962085308,,,
# 109,415312,1744,0.020724251260759458,0.6875,0.9783393501805054,,,
# 110,418656,1760,0.024428871761111106,0.625,0.9797297297297297,,,
# 111,423152,1776,0.01985703725633799,0.4375,0.9625,,,
# 112,425984,1792,0.027673566569924844,0.4375,0.9383259911894273,,,
# 113,429200,1808,0.025661445221013386,0.3125,0.950207468879668,0.031116881985316647,0.3125,0.9299610894941635
# 114,431776,1824,0.027542793283439844,0.5,0.96875,,,
# 115,436656,1840,0.021695763076084607,0.3125,0.9318181818181818,,,

# %% [markdown]
# ## 3.3 Using the fine-tuned models
#
# We will now use the fine-tuned discriminator and the fine-tuned Q&A model. By requesting logprobs, we can see how certain the discriminator is in a `yes` vs `no` answer.

# %%
ft_discriminator = "ft:babbage-002:simin::8Uu2jz0r"

def apply_ft_discriminator(question, discriminator_model):
    """
    Apply the fine tuned discriminator to a question, to assess whether it can be answered from the context.
    """
    prompt = f"{question}\n\n###\n\n"
    result = openai.Completion.create(model=discriminator_model, prompt=prompt, max_tokens=1, temperature=0)
    result_prob = openai.Completion.create(model=discriminator_model, prompt=prompt, max_tokens=1, temperature=0, top_p=1, n=1, logprobs=2)
    return result['choices'][0]['text'], result_prob['choices'][0]['logprobs']['top_logprobs'][0]

# %%
q1,q2 = apply_ft_discriminator('I would like to crawl an Ethereum network completely, is there any way?', ft_discriminator)

# %%
q1
# Out:
# '0'

# %%
q2
# Out:
# <OpenAIObject at 0x2cdc5dbf130> JSON: {
#   ",": -23.966797,
#   "0": 0.0
# }

# %%
q3,q4 = apply_ft_discriminator('How does that work? Overlays? FS changes are not stored?', ft_discriminator)

# %%
q3
# Out:
# '0'

# %%
q4
# Out:
# <OpenAIObject at 0x2cd87835e50> JSON: {
#   "0": 0.0,
#   "1": -22.293943
# }

# %%
q5,q6 = apply_ft_discriminator('[code] why the title is not showing?', ft_discriminator)

# %%
q5
# Out:
# '1'

# %%
q6
# Out:
# <OpenAIObject at 0x2cd87835c20> JSON: {
#   "1": 0.0,
#   "2": -20.043943
# }

# %%
ft_discriminator = "ft-CIxlKEkKfa0v9FmPiuNQZSGc"


def apply_ft_discriminator2(question, discriminator_model):
    """
    Apply the fine tuned discriminator to a question, to assess whether it can be answered from the context.
    """
    prompt = f"Question: {question}\nAnswer:"
    result = openai.Completion.create(model=discriminator_model, prompt=prompt, max_tokens=1, temperature=0, top_p=1, n=1, logprobs=2)
    return result['choices'][0]['logprobs']['top_logprobs']

apply_ft_discriminator('The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957.', 
                        'What was the first human-made object in space?', ft_discriminator)
# Out:
# [<OpenAIObject at 0x7fe812e602b0> JSON: {
#    " no": -10.819577,
#    " yes": -2.045765e-05
#  }]

# %%
df.loc[568].Issues
# Out:
# 'Hey guys, can somebody explain me what it means "uncle root" in the whitepaper of ethereum in github? in the next sentence..."Check that the block number, difficulty, transaction root, uncle root and gas limit (various low-level Ethereum-specific concepts) are valid." Thank you so much!'

# %% [markdown]
# We can see that the model can generalize well to different contexts and questions.

# %%
ft_qa = "curie:ft-personal-2023-05-18-03-46-16"
openai.api_key = api_key

def apply_ft_qa_answer(question, answering_model):
    """
    Apply the fine tuned discriminator to a question
    """
    prompt = f"Question: {question.strip()}\nAnswer:"
    result = openai.Completion.create(model=answering_model, prompt=prompt, max_tokens=100, temperature=0, top_p=1, n=1, stop=['.','\n'])
    return result['choices'][0]['text']

#apply_ft_qa_answer(df.loc[0].Issues, ft_qa)

# %%
test_df.reset_index(inplace=True, drop=True)
test_df.loc[0].Issues
# Out:
# 'Guys any thoughts as to why adding the followingtransformProcessBuilder = transformProcessBuilder.filter(new ConditionFilter(new DoubleColumnCondition("ZYISP", ConditionOp.GreaterOrEqual, 150.0)));would cause a NullPointerException at RecordReaderMultiDataSetIterator.convertWritables? Does the convertWritables take the size of the list of entries before the filter is applied or something? Surely that would never work in that case?'

# %%
tests = [test_df.loc[i].Issues for i in range(len(test_df))]
results = []
for issue in tests:
    results.append(apply_ft_qa_answer(issue, ft_qa))

# %%
results
# Out:
# ['The sentence "adding the followingtransformProcessBuilder = transformProcessBuilder',
#  'Not found PS',
#  'The sentence "I\'m struggling withNd4j',
#  'The sentence "i\'m getting this error:" describes PS',
#  'Not found PS',
#  'The sentence "Not sure what this error is about" describes PS',
#  'The sentence "I\'m quite new to Java and so far have failed to get ND4J\'s unit tests up and running" describes PS',
#  'Not found PS',
#  'The sentence "but the problem is that the nodejs won\'t connect to the redis instance',
#  'The sentence "I am a bit confused" describes PS',
#  'The sentence "I can\'t  understand this case;" describes PS',
#  'The sentence "This is on a machine without actual CUDA GPU" describes PS',
#  'Not found PS',
#  'Not found PS',
#  'The sentence "but now stuck getting 3rd party library errors on Omit and Diff or is it possible to ignore invalid types in node_modules in 2',
#  'The sentence "this done portion is giving me error from passport local mongoose tha user',
#  'The sentence "crawling with a problem for 2 days" describes PS',
#  'The sentence "I get the following error:" describes PS',
#  'Not found PS',
#  'The sentence "it returns 0\'s because the vocab Cache doesn\'t save the total Number of documents which is needed for calculating idf" describes PS',
#  'The sentence "the last 2 console logs will print out as \'undefined\'" describes PS',
#  'Not found PS',
#  'The sentence "The CSVSequenceRecordReader example does not work for me as I have to create 1 file per sequence',
#  'Not found PS',
#  'Not found PS',
#  'Not found PS',
#  'The sentence "I just can\'t find the reason for the error still the same error" describes PS',
#  'The sentence "but it still gives me the same error message for the same code" describes PS',
#  'Not found PS',
#  'Not found PS',
#  'Not found PS',
#  'The sentence "but It seems like I can\'t add my peer" describes PS',
#  'The sentence "My question is about the excessive memory usage of docker-compose on the current version',
#  'The sentence "I am writing multiple test , so while starting second test it gives me this org',
#  'The sentence "still working up the issue',
#  'Not found PS',
#  'The sentence "but find that when I close the UI the 4 background process continue to run which wouldn\'t have been an issue except that the GUI doesn\'t restart when I click the application icon',
#  'Not found PS',
#  'The sentence "I am using Nodejs with VS2017 and struggling to get my gulp, mocha testing bits working together properly it seems gulp has landed in my C:\\\\Users',
#  'The sentence "but when using appium, app freezes and looks like appium enters a race condition" describes PS',
#  'The sentence "but latest typings doesn\'t allow that anymore" describes PS',
#  'Not found PS',
#  'Not found PS',
#  'The sentence "every container and every image was removed" describes PS',
#  'Not found PS',
#  'The sentence "I have question aboutkoa-bodyParse',
#  'The sentence "but it seems the only thing it stores are the vectors, not the words" describes PS',
#  'The sentence "I get a typescript error in the ide  [<-CODE->]" describes PS',
#  'Not found PS',
#  'The sentence "However the compiler complains that my input props on the generic don\'t satisfy it:" describes PS',
#  'The sentence "cron',
#  'Not found PS',
#  'The sentence "I just found the following behavior (bug?) in TypeScript, where using function f(o: X) behaves strange, while function f<T extends X>(o: T) works perfectly:" describes PS',
#  'Not found PS',
#  'The sentence "but I am getting an error Uncaught TypeError:" describes PS',
#  'The sentence "but getting the dreaded node-gyp rebuild error Failed at the contextify@0',
#  'The sentence "it has iterator',
#  'Not found PS',
#  'The sentence "but got a exception:" describes PS',
#  'The sentence "I still get this error message, though the application master node is listening on the given udp port" describes PS',
#  'Not found PS',
#  'The sentence "i am facing one issue',
#  'The sentence "But it is not returned to my portfolio" describes PS',
#  'Not found PS',
#  'The sentence "when Conv2D of the same dimension runs successfully" describes PS',
#  'The sentence "it throws a rather peculiar error" describes PS',
#  'Not found PS',
#  'The sentence "im getting the error Exception in thread "main" java',
#  'Not found PS',
#  'The sentence "The following exception occurs:" describes PS',
#  'The sentence "and it does not stop now',
#  'Not found PS',
#  'The sentence "im always "Out of [DEVICE] memory", is it somehow possible to adjust workspace modes for arbiter" describes PS',
#  'The sentence "However, when I set the backend to use cuda it takes forever to load the model',
#  'The sentence "but it the project is located to documents/folder with spaces/folder (with) parentesis it doesn\'t work" describes PS',
#  'The sentence "the former I would just zoom out like 10 to 20% and worked \'good enough\'" describes PS',
#  'Not found PS',
#  'The sentence "I\'m getting errorValidation failedwhen trying to create a room" describes PS',
#  'The sentence "but it throws me the next error:" describes PS',
#  'The sentence "this code compiles where I thought it shouldn\'t" describes PS',
#  'Not found PS',
#  'Not found PS',
#  'The sentence "but throws anUnsupportedOperationExcpetion exception at org',
#  'Not found PS',
#  'The sentence "my page is served, but the links to JS/CSS files are not there" describes PS',
#  'The sentence "And I would like to be possible to manage my rabbitmq queues running in the php container by the supervisor container (using some web ui)" describes PS',
#  'The sentence "This is a reduced example, in real world code the first argument is too complex to get manual annotation I guess there is some problem in overloading resolution and contextual inference, but cannot debugging further deeper',
#  'Not found PS',
#  'Not found PS',
#  'Not found PS',
#  'The sentence "The build fails',
#  'The sentence "I am running a dl4j based app on an Amazon Linux AMI with NVIDIA GRID GPU Driver node and get ajava',
#  'Not found PS',
#  'Not found PS',
#  'The sentence "I can\'t get my model to learn anything',
#  'The sentence "but issue remains with usingdocker-compose up',
#  'The sentence "Error:(10, 16) TS2345: Argument of type \'typeof User\' is not assignable to parameter of type \'new () => User\x82Äô" describes PS',
#  'The sentence "but cl',
#  'The sentence "Failed to allocate 878103121 bytes from DEVICE [0] memory" describes PS',
#  'The sentence "Error:(3, 26) java: package javafx',
#  'The sentence "However, I think this causes a problem since a flattened matrix can\'t be rotated because it fails the isMatrix test',
#  'Not found PS',
#  'The sentence "I get this error" describes PS',
#  'The sentence "I\'m setting the Content-type to \'multipart/form-data\' with multer plugin and always that I try to send the request node returns this error for me" describes PS',
#  'Not found PS',
#  'The sentence "I seem to have to run npm upgrade to get the latest versions even though my package',
#  'The sentence "Most of the cases the EarlyStopping stops the learning in the 5th epoch and the best epoch reported is 0" describes PS',
#  'The sentence "but, while running a training log says" describes PS',
#  'The sentence "calls to the api with postman still work fine, do I need to do something on the browser side, or do I need something in my angular code to enable https calls?" describes PS',
#  'Not found PS',
#  'The sentence "i have some trouble using webpackhotmiddleware within a express',
#  'Not found PS',
#  'Not found PS',
#  'Not found PS']

# %%
test_df
# Out:
#                                                 Issues PS ETD TS AR  Q
# 0    Guys any thoughts as to why adding the followi...  Y   N  N  N  Y  \
# 1    the mnist MLPMnistSingleLayer example was expl...  N   N  Y  Y  Y
# 2    I'm struggling withNd4j.sortWithIndices(lookup...  Y   Y  N  N  N
# 3    I'm trying to import a model with DL4J but i'm...  Y   Y  Y  Y  Y
# 4    I'm creating a new platform on Ethereum. The i...  Y   Y  N  N  Y
# ..                                                 ... ..  .. .. .. ..
# 109  LSTM layers require quite a bit of memory, don...  N   N  N  N  Y
# 110  hi guys ! i have some trouble using webpackhot...  Y   N  N  N  Y
# 111  Just asking my question from earlier again in ...  N   N  N  N  Y
# 112  Hey, is there native compiler for typescript? ...  Y   Y  N  N  Y
# 113  is it actually possible to separate a type def...  N   Y  N  N  Y
#
#     Complete?                                            PS_sent
# 0           N                 would cause a NullPointerException  \
# 1           N                                                  N
# 2           N  I'm struggling withNd4j.sortWithIndices(lookup...
# 3           Y                            i'm getting this error:
# 4           N                 The issue I see arising is funding
# ..        ...                                                ...
# 109         N                                                  N
# 110         N  i have some trouble using webpackhotmiddleware...
# 111         N                                                  N
# 112         N  and it takes a lot of time to distribute (and ...
# 113         N                                                  N
#
#                                               ETD_sent
# 0                                                    N  \
# 1                                                    N
# 2        I'm trying to get the index for the glossary
# 3              I'm trying to import a model with DL4J
# 4     I would like to have a reputable developer ad...
# ..                                                 ...
# 109                                                  N
# 110                                                  N
# 111                                                  N
# 112  By native I mean something written in c++ or c...
# 113   I'd like to type it  at some other place for ...
#
#                                                TS_sent
# 0                                                    N
# 1    I have tried for hours to hack it out by using...
# 2                                                    N
# 3        I checked the json file i'm importing though
# 4                                                    N
# ..                                                 ...
# 109                                                  N
# 110                                                  N
# 111                                                  N
# 112                                                  N
# 113                                                  N
#
# [114 rows x 10 columns]

# %%
df_result = pd.DataFrame()
df_result["Issue"] = test_df["Issues"]
df_result["predicted"] = results
df_result["truth"] = test_df["PS"]

# %%
df_result
# Out:
#                                                  Issue
# 0    Guys any thoughts as to why adding the followi...  \
# 1    the mnist MLPMnistSingleLayer example was expl...
# 2    I'm struggling withNd4j.sortWithIndices(lookup...
# 3    I'm trying to import a model with DL4J but i'm...
# 4    I'm creating a new platform on Ethereum. The i...
# ..                                                 ...
# 109  LSTM layers require quite a bit of memory, don...
# 110  hi guys ! i have some trouble using webpackhot...
# 111  Just asking my question from earlier again in ...
# 112  Hey, is there native compiler for typescript? ...
# 113  is it actually possible to separate a type def...
#
#                                              predicted truth
# 0    The sentence "adding the followingtransformPro...     Y
# 1                                         Not found PS     N
# 2                The sentence "I'm struggling withNd4j     Y
# 3    The sentence "i'm getting this error:" describ...     Y
# 4                                         Not found PS     Y
# ..                                                 ...   ...
# 109                                       Not found PS     N
# 110  The sentence "i have some trouble using webpac...     Y
# 111                                       Not found PS     N
# 112                                       Not found PS     Y
# 113                                       Not found PS     N
#
# [114 rows x 3 columns]

# %%
df_result.to_csv("finaldata/result.csv",index=None)

# %% [markdown]
# We can see that the model can answer the question, when the context is appropriate.

# %%
apply_ft_qa_answer(df.loc[568].Issues, ft_qa)
# Out:
# 'Not found PS'

# %%
apply_ft_qa_answer(df.loc[3].Issues, ft_qa)
# Out:
# 'The sentence "i am facing some issue with typescript where i have a state object and i am trying to update the state with the key of the object being dynamic" describes PS'

# %%
apply_ft_qa_answer("Does anyone know how to import or require a node module  from any ts file?", ft_qa)
# Out:
# 'Not found PS'

# %%
apply_ft_qa_answer("I'm having trouble deciding how to add an element to the DOM with a click event. Not sure if I don't have the right query or what. Any recommendation?", ft_qa)
# Out:
# 'Not found PS'

# %%
apply_ft_qa_answer("I'm getting familiar with classes and `def __init__(self, variable)` and I'm struggling with accessing a function from within my class.The function above works as intended outside my class. How do I access the same function and when placed inside my class? What I want is to write a print statement outside my class. I tried this one with no success. The traceback I get is ```TypeError: address_lookup() missing 1 required positional argument: 'address'``", ft_qa)
# Out:
# 'The sentence "I\'m having an issue with the new forms api'

# %%
apply_ft_qa_answer("I'm getting familiar with classes and `def __init__(self, variable)` and I'm struggling with accessing a function from within my class.The function above works as intended outside my class. How do I access the same function and when placed inside my class? What I want is to write a print statement outside my class. I tried this one with no success. The traceback I get is ```TypeError: address_lookup() missing 1 required positional argument: 'address'", ft_qa)
# Out:
# 'The sentence "I\'m getting familiar with classes and `def __init__(self, variable)` and I\'m struggling with accessing a function from within my class'

# %% [markdown]
# We can see that the model knows when to answer the question, and when to say that insufficient context is present to answer the question.

# %% [markdown]
# We can also combine a discriminator and a base model, or a fine-tuned Q&A model. Discriminator can essentially serve as a decision whether the question can be answered given the context or not.

# %%
def answer_question_conditionally(answering_model, discriminator_model, context, question, discriminator_logprob_yes_modifier=0):
    logprobs = apply_ft_discriminator(context, question, discriminator_model)
    yes_logprob = logprobs[' yes'] if ' yes' in logprobs else -100
    no_logprob = logprobs[' no'] if ' no' in logprobs else -100
    if yes_logprob + discriminator_logprob_yes_modifier < no_logprob:
        return " No appropriate context found to answer the question based on the discriminator."
    return apply_ft_qa_answer(context, question, answering_model)
answer_question_conditionally(ft_qa, ft_discriminator, 
                                "Crowdless games are a rare although not unheard-of occurrence in sports. \
                                 When they do occur, it is usually the result of events beyond the control \
                                 of the teams or fans, such as weather-related concerns, public health concerns, \
                                 or wider civil disturbances unrelated to the game. For instance, \
                                 the COVID-19 pandemic caused many sports leagues around the world \
                                 to be played behind closed doors.",
                                "Could weather cause a sport event to have no crowd?")
# Out:
# ' Weather could cause a sport event to have no crowd'

# %% [markdown]
# The above function illustrates how to potentially combine a discriminator and a fine-tuned Q&A model. This gives a more fine-grained control over how certain we want the model to be before it answers the question.
#
# We'll now take a look on how answers endpoint works - combining search to retrieve the relevant context from a knowledge base, and then using the fine-tuned Q&A model to answer the question.

# %% [markdown]
# ## 3.4 Answering the question based on a knowledge base
# Finally we can use a logic similar to the [/answers](https://beta.openai.com/docs/api-reference/answers) endpoint, where we first search for the relevant context, and then ask a Q&A model to answer the question given that context. If you'd like to see the implementation details, check out the [`answers_with_ft.py`](answers_with_ft.py) file.

# %%
from answers_with_ft import answer_question
answer_question(olympics_search_fileid, ft_qa, "Which country won the Women's football tournament at the 2020 Olympic games?")
# Out:
# " Canada won the Women's football tournament at the 2020 Olympic games"
